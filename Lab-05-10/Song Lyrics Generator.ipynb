# %% [markdown]
# # Song Lyrics Generator
# ## Due Tuesday, May 17 at 8 AM
#
# In this lab, you will scrape the web to get lyrics from your favorite artist. Then, you will train a Markov Chain model on these lyrics. Finally, you will use your Markov chain to generate new (random) lyrics.

# %% [markdown]
# ## Question 1: Web Scraping (40 points)
#
# Find a website that has lyrics for all the songs by your favorite artists. Then scrape the lyrics into a Python list called `lyrics`, where each element of the list represents the lyrics of one song.
#
# Tips:
# - Find a webpage that has links to all the songs, like [this one](http://www.azlyrics.com/n/nirvana.html). [NOTE: It seems like azlyrics.com does not allow you to scrape their webpages, so you'll have to find another source.] Then, you can write code to visit all the links and scrape each page one by one.
# - Make sure you use time.sleep(0.1) to stagger your requests so that you do not get banned by the website for making too many requests.

# %%
import requests
import time
from bs4 import BeautifulSoup
import bs4

lyrics = []

# <table class = ..>
    #<tbody>
        #for all <tr> tag
            # array of <td>[1] //second td tag in list
                    
                #access a tag
                    #hyper link = arr of <td>[1]['href'] // to get the hyperlink of song lyrics
                    #go to hyperlink and parse the html
                
                    #<sd-lyricbody
                        #<div class = "...">
                            #<div id = "lyrics-body-text"
                                #find all p-class ="verse"
                                    #for each verse p tag
                                        #add pverse.string to temp variable to hold string of lyrics for single song
                                        #append string of lyrics to list of lyrics
                        

page = requests.get("http://www.metrolyrics.com/green-day-alpage-1.html")
time.sleep(0.1)
source = BeautifulSoup(page.text, "html.parser")

canStillRun = True

while(canStillRun == True):

    #print(source.find("a", class_= "button next disabled") == None)

    table_class = source.find("table", class_= "songs-table compact")
    #print( table_class != None)

    t_body = table_class.find("tbody")
    tr_s = t_body.find_all("tr") #returns a list of trs that contain link to other page (links to lyrics of songs)

    for tr in tr_s: #for each song.. on page x...
        
        list_of_tds = tr.find_all("td")
        
        
        atag_under_tds_list = list_of_tds[1].find('a')

        href_hyperlink = atag_under_tds_list['href']

        #go to link to lyrics
        lyric_page = requests.get(href_hyperlink)
        time.sleep(0.1)
        lyric_source = BeautifulSoup(lyric_page.text, "html.parser")
       
        div_id_lyrics_body = lyric_source.find('div', class_ = "js-lyric-text")

        tmp_lyrics_singlesong = ""

        verses_list = div_id_lyrics_body.find_all('p')

        for verse_tag in verses_list:
    
            verse_filtered = str(verse_tag).replace("<p class=\"verse\">", "" ).replace('<br>', "").replace("</br>", "").replace("\n", " ").replace("</p>", "\n\n")
            tmp_lyrics_singlesong += verse_filtered
    
        lyrics.append(tmp_lyrics_singlesong)

    #After done adding lyrics of each song to main list, advance to next page
    
    #if next button is disabled, break out of loop
    
    if(source.find("a", class_= "button next disabled") == None):
        
        a_tag_toNextPage = source.find("a", class_= "button next")
        href_hyperlink = a_tag_toNextPage['href']
        
        page = requests.get(href_hyperlink)
        time.sleep(0.1)
        source = BeautifulSoup(page.text, "html.parser")
    else:
        
        canStillRun = False

# %%
print(lyrics[0])
# Out:
# Hey Gloria, are you standing close to the edge? Look out to the setting sun, the brink of your vision Eternal youth is a landscape of a lie
#
# The cracks of my skin can prove, as the years will testify Say your prayers and light a fire, we're going to start a war Your slogan's 'A gun for hire,' it's what we waited for
#
# Hey Gloria, this is why we're on the edge The fight of our live's been drawn in this undying love
#
# Gloria, Viva La Gloria You blast your name in graffiti on the walls Falling in broken glass and slashing through your spirits I can hear it like a jilted crowd
#
# Gloria, where are you Gloria? You found a home in all your scars and ammunition You made your bed in salad days amongst the ruins Ashes to ashes of our youth
#
# She smashed her knuckles into winter (Gloria!) As autumn's wind fades into black She is the saint of all the sinners (Gloria!) The one that's fallen through the cracks So don't put away your burning light
#
# Gloria, where are you Gloria? Don't lose your faith to your lost naivete Weather the storm and don't look back on last November When your banners were burning down
#
# Gloria, Viva La Gloria Send me your amnesty down to the broken-hearted Bring us the season that we always will remember Don't let the bonfires go out
#
# So Gloria, send out your message of The light that shadows in the night Gloria, where's your undying love? Tell me the story of your life Your life!

# %% [markdown]
# ## Question 2: Training a Markov Chain (30 points)
#
# Markov chains are mathematical systems that hop (a.k.a. "transition") randomly between various states. Please read [this visual explanation](http://setosa.io/ev/markov-chains/) for a high-level overview. The distinguishing feature of a Markov chain is that the next state only depends on which state the chain is in now; it doesn't depend on the past history of the chain.
#
# We can use Markov chains to model human language. Each word is a "state", and the next word in a sentence only depends on the current word, not any words that came before. This model makes sense because if we know that the current word is "it", the next word is very likely to be "is", less likely to be "runs", and never going to be "pineapple". On the other hand, if the current word is "the", then the next word might be "pineapple", but it can't be "is". The current word tells us a lot about what the next word might be.
#
# We will build a Markov chain model for the artist whose lyrics you scraped in Question 1. To do this, we have to go through the lyrics and learn the word transitions for that artist. We will store this information in a dict called `transitions`, which maps each word to a list of words that appear after it in the training data. So for example, one entry of this dict might be
#
# ```
# transitions = {
#     "it": ["is", "runs", "is", "is", "was", "is", "was"],
#     ...
# }
# ```
#
# You should include a few additional states, besides words, in your Markov chain. You should have `"<START>"` and `"<END>"` states so that we can keep track of what words songs are likely to begin and end on.  So if the song starts on the word "it" and ends with the word "me.", you would have
# ```
# transitions = {
#     "<START>": ["it", ...],
#     "me.": ["<END>", ...],
#     ...
# }
# ```
# You should also include a state called `"<N>"` to denote line breaks so that we know where lines begin and end.

# %%
def rreplace(s, old, new, occurrence): #works on a string, not list; replaces last n occurences of old instance with new
    li = s.rsplit(old, occurrence)
    return new.join(li)

def train_markov_chain(lyrics):
    transitions = {"<START>": []}
    
    for lyric in lyrics:
        
        string1 = lyric.replace("\n\n", " <N> ")
        string1b = rreplace(string1, "<N>", "", 1)

        string2 = "<START> " + string1b + "<END>"
        string3 = string2.split(" ") #each song lyrics are broken up into a list of words.
        string3.remove("")


        index = 0 # for list of words

        for word in string3:

            #print(word)

            if word not in transitions:

                transitions[word] = []
                if index + 1 < len(string3):

                    transitions[word].append(string3[index+1])
            else:

                if index + 1 < len(string3):

                    transitions[word].append(string3[index+1])

            index += 1
    
    #print(string3)
    return transitions

transitions = {}


    
for lyric in lyrics:
        
    string1 = lyric.replace("\n\n", " <N> ")
    string1b = rreplace(string1, "<N>", "", 1)
    
    string2 = "<START> " + string1b + "<END>"
    string3 = string2.split(" ") #each song lyrics are broken up into a list of words.
    string3.remove("")
    
    
    index = 0 # for list of words
    
    for word in string3:
        
        #print(word)
        
        if word not in transitions:
            
            transitions[word] = []
            if index + 1 < len(string3):

                transitions[word].append(string3[index+1])
        else:
            
            if index + 1 < len(string3):

                transitions[word].append(string3[index+1])
            
        index += 1
    
    #print(string3)
transitions
# Out:
# {'': ['<END>', '<END>', '<END>', '<END>', '<END>', '<END>'],
#  'scattered': ['dreams', 'dreams', 'pictures', 'pictures'],
#  'Ramones]': ['<N>', '<N>'],
#  'Jane': ['To', 'To', 'To', 'Street', 'Street'],
#  'doubt': ['about',
#   'I',
#   'Now',
#   'Now',
#   'Now',
#   'With',
#   'With',
#   'about',
#   'about',
#   'Singled',
#   'But',
#   'I'],
#  '2:': ['Oasis(Band)]', 'East'],
#  'strangers': ['<N>', 'Get', 'now', 'Christmas'],
#  'bouncin\x7faround': ['everywhere'],
#  'hurry?': ['I', 'I'],
#  'Spontaneous': ['combustion,', 'combustion'],
#  'Crying': ['Town]'],
#  'Ie': ['been', 'got'],
#  'claustrophobic': ['mind'],
#  'paperwork': ['now,', 'now,', 'now', 'now'],
#  'happened': ['again',
#   'again',
#   'Tuesday',
#   'to',
#   'long',
#   'long',
#   'long',
#   'long'],
#  'shagging': ['in'],
#  'drama': ['queens'],
#  'eating': ['crow'],
#  'guide': ['them'],
#  'burning': ['light',
#   'down',
#   'down',
#   'light',
#   'down',
#   'up',
#   'out',
#   'out',
#   'out',
#   'out',
#   'out',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'red',
#   'down',
#   'down',
#   'daylight'],
#  'bleeds': ['beyond', 'into', 'into'],
#  'Mascara': ['tears', 'tears'],
#  'erased': ['yourself', 'Guess', 'Guess'],
#  'losers,': ["can't", "can't"],
#  'Remember': ['to', 'when', 'when', 'when', 'Whatever', 'Whatever'],
#  'Rastaferi': ['goes'],
#  'sucker': ['for'],
#  'ON': ['A', 'HOLY', 'THE'],
#  "Lydia'll": ['bring'],
#  'fucked,': ["don't"],
#  'Trapped': ['inside'],
#  'buy': ['<N>'],
#  'mud': ['Cut', 'Cut', 'It', '<N>', '<END>', '<N>', '<N>'],
#  'Seasons': ['in', 'change', 'greeting'],
#  'BURNING': ['TO', 'OUT', 'DOWN'],
#  'frames': ['in', 'in', 'in', 'in', 'in', 'in', 'in'],
#  'say,"The': ['time'],
#  'unfair,': ['well'],
#  'Gotta': ['build',
#   'get',
#   'be',
#   'be',
#   'hold',
#   'hold',
#   'hold',
#   'hold',
#   'live',
#   'make',
#   'do',
#   'live',
#   'make',
#   'do',
#   'live',
#   'make',
#   'do',
#   'live',
#   'make',
#   'do',
#   'let',
#   'let',
#   'ride',
#   'move'],
#  'plain': ['sight', 'all'],
#  'Christ': ["You'd"],
#  'alright....': ['<N>', '<N>', 'The', 'The', '<END>'],
#  'mission': ['Into', 'Into', 'Into', 'I', "I've", '<N>', 'to'],
#  'flame': ['burns', '(hey!)', '(hey!)', '<N>'],
#  'running': ['around?',
#   'around?',
#   'around?',
#   'around?',
#   'around?',
#   'out',
#   'free',
#   'free',
#   'out',
#   'out',
#   'out',
#   'out',
#   'at',
#   'the',
#   'with',
#   'with',
#   'As',
#   'As',
#   'red',
#   'red',
#   'out',
#   'out',
#   'underground',
#   'wild',
#   'out',
#   'out',
#   'out',
#   'out',
#   'out',
#   'Just',
#   'with'],
#  'sun,': ['the', 'the'],
#  "Hatin'": ['every', 'every'],
#  'mind': ['breaks',
#   'To',
#   'To',
#   'if',
#   'I',
#   'is',
#   'fuck',
#   'Elected',
#   '[Incomprehensible]',
#   "I'm",
#   '<END>',
#   'with',
#   'On',
#   'is',
#   'plays',
#   'plays',
#   'plays',
#   '<N>',
#   'On',
#   'On',
#   'On',
#   '<N>',
#   'is',
#   '<N>',
#   'is',
#   '<N>',
#   '<N>',
#   "I'll",
#   'While',
#   'While',
#   'While',
#   'A',
#   'A',
#   'is',
#   'is',
#   'Like',
#   "It's",
#   "It's",
#   '<N>',
#   '<N>',
#   'Ahhh',
#   'I',
#   'Kiss',
#   'I',
#   'Hang',
#   'Hang',
#   'Hang',
#   'Hang',
#   'Hang',
#   'And',
#   "She's",
#   "She's",
#   'I',
#   'and',
#   'and',
#   'To',
#   'is',
#   "it's",
#   'On',
#   'is',
#   'is',
#   'is',
#   'Ahhh',
#   'if',
#   'Well',
#   'if',
#   "You're",
#   'control',
#   '<N>',
#   '<N>',
#   'is',
#   "It's",
#   "It's",
#   "It's",
#   'And',
#   'Flashing',
#   'Flashing',
#   'Of',
#   'Of',
#   'Of',
#   '<N>',
#   'When',
#   '<N>',
#   'if',
#   'To',
#   '<N>',
#   "I'll",
#   "I'll",
#   "I'll",
#   "I'll",
#   "I'll",
#   'I',
#   'Waiting',
#   '<N>',
#   "I'm",
#   "I'm",
#   'Just',
#   'Land',
#   'Just',
#   'to',
#   'to',
#   'Is',
#   'Is',
#   'in',
#   'all',
#   'Better',
#   'Better',
#   'Are',
#   'Hang',
#   'Hang',
#   "It's",
#   '<N>',
#   'is',
#   "She's",
#   "She's",
#   "She's",
#   "She's",
#   "I'm",
#   'instead',
#   'to',
#   '<N>',
#   'on',
#   'off',
#   'Shake',
#   'Shake'],
#  'headstone': ['<N>', '"Icon"'],
#  'would': ['forever',
#   'forever',
#   'forever',
#   'understand?',
#   'understand?',
#   'understand?',
#   'like',
#   'end',
#   'end.......',
#   'find',
#   'find',
#   'stop',
#   'be',
#   'be',
#   'be',
#   'be',
#   'come',
#   'you',
#   'you',
#   'end',
#   'end',
#   'realize',
#   'realize',
#   'realize',
#   'you',
#   'be',
#   'please',
#   'step'],
#  'harm': ['But'],
#  'LOVE': ['BUT', 'BUT'],
#  'big': ['old',
#   'sensation.',
#   'sensation.',
#   'deal',
#   'plans',
#   'plans',
#   'on',
#   'you'],
#  'stood': ['a'],
#  'town)': ['My'],
#  'disappointments': ['you', 'you', 'you'],
#  'Heinekin,': ['fuck'],
#  'demise': ['<N>', '<N>', '<N>'],
#  'waste': ['away',
#   'away',
#   'my',
#   'away',
#   'my',
#   'away',
#   'my',
#   'is',
#   'it,',
#   'my',
#   'my',
#   'like',
#   'your',
#   'like',
#   'your',
#   'like',
#   'your',
#   'your',
#   'your',
#   'your',
#   'but',
#   'another',
#   'a'],
#  'laughter,': ['sing'],
#  'attention': ['Got', 'Teaching', 'Teaching', 'Teaching', 'to', 'to', 'to'],
#  'cemetery': ['so', 'drive', 'drive'],
#  'stuck': ['And',
#   'with',
#   'with',
#   'with',
#   'with',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'my'],
#  '(more': ['instrumental)'],
#  'masochists': ['<N>', '<N>', '<N>'],
#  'reside': ['in', 'in', 'in'],
#  'plan,': ['Got', 'For'],
#  'built': ['to'],
#  'fun': ['yea',
#   'But',
#   'But',
#   'Gonna',
#   'Gonna',
#   '<N>',
#   "(Where'd",
#   '<END>',
#   "(where'd",
#   "(where'd",
#   '<END>',
#   'I',
#   'I',
#   '<N>',
#   "You're",
#   'and',
#   'have',
#   'Everyone',
#   '<END>',
#   'More',
#   'Oh,',
#   'In',
#   'In',
#   'and',
#   'and',
#   'and',
#   'she',
#   '<END>'],
#  'eve': ['of', 'of'],
#  'elated': ['Medicated', 'Medicated'],
#  'thank': ['you}', 'your', 'your', 'your'],
#  'Sucking': ['up', 'up'],
#  'noose': ['over',
#   'over',
#   'over',
#   'over',
#   'over',
#   'over',
#   'so',
#   'so',
#   '<N>',
#   '<N>',
#   '<N>',
#   '<N>'],
#  'escape': ['On', 'from'],
#  'we': ['waited',
#   'always',
#   'start',
#   'laugh',
#   'forget?',
#   'should',
#   'can',
#   'can',
#   'waited',
#   'always',
#   'go....',
#   'go....',
#   'go....',
#   'go....',
#   'have',
#   'go',
#   'go',
#   'go',
#   'go',
#   'go',
#   'go',
#   'go',
#   'go',
#   'go',
#   'used',
#   'used',
#   'all',
#   'all',
#   'all',
#   'all',
#   'all',
#   'all',
#   'all',
#   'all',
#   'go',
#   'go',
#   'demented',
#   'can',
#   'kill',
#   'will',
#   'torched',
#   'torched',
#   'had',
#   'torched',
#   'torched',
#   'had',
#   'go',
#   'go',
#   'spent',
#   'had',
#   'both',
#   'demented',
#   'demented',
#   'demented',
#   'part',
#   'find',
#   'might',
#   'all',
#   'say',
#   'buy,',
#   "can't",
#   'get',
#   'all',
#   'all',
#   'wanna',
#   "couldn't",
#   'have',
#   'have',
#   'are',
#   'are',
#   'are',
#   'go',
#   'go',
#   'were',
#   'will',
#   'shared',
#   'are',
#   'are',
#   'shared',
#   'are',
#   'still',
#   'can',
#   'run',
#   'take',
#   'kill',
#   'all',
#   'remember',
#   'find',
#   'find',
#   'go',
#   'go',
#   'are',
#   'party',
#   'need',
#   'need',
#   'need',
#   'are',
#   'did',
#   'are',
#   'are',
#   'did',
#   'are',
#   'are',
#   'did',
#   'are',
#   'go',
#   'go'],
#  'prayers': ['and', 'and'],
#  'spine': ['My', 'My', 'My', "Nothing's", '<N>', '<N>', '<N>', '<N>', '<END>'],
#  "cruisin'": ['son'],
#  "belly's": ['aching', 'aching', 'aching', 'aching', 'aching', 'aching'],
#  'possibility?': ['Get', 'Get', 'Get', 'Get'],
#  'bring': ['you', 'you', 'you', 'you', 'to'],
#  'special': ['friend', 'kind', 'at', 'kind', 'kind', 'occasion?'],
#  'August': ['Grudges', 'Grudges'],
#  '(Say': ['you', 'you', 'you', 'you', 'you', 'you'],
#  'line:': ['you', 'you'],
#  'gratified': ['You'],
#  'crushing': ['my'],
#  'lovely': ['faces'],
#  'honesty': ['I', 'I', 'I'],
#  "givin'...": ['<N>', '<N>', '<N>'],
#  'denin\x7fShe': ['keeps'],
#  'evacuation': ['protest'],
#  'Feels': ['so'],
#  'done': ['Ask', 'with', "It's", "It's", "There's", 'Until', 'Thank'],
#  'detonate!': ['<N>'],
#  'vast': ['majority', 'majority'],
#  'finally': ['lost', 'lost', 'figured', 'got', 'met', 'found'],
#  'dogs': ['who', "howlin'", "howlin'"],
#  'Sorry': ['for'],
#  'NO!!': ['Do'],
#  'choke': ['you', 'you', 'on', 'on', 'on'],
#  'cracked': ['streets', 'streets', 'streets'],
#  'hazy': ['To', 'To', 'To'],
#  "changin'": ['<N>'],
#  'picking': ['scabs', 'scabs', 'scabs', 'at'],
#  'Homeland': ['security'],
#  'BLOODSUCKERS': ['SING', 'SING'],
#  'explode': ['<N>'],
#  'dark': ['In', 'In', 'Blinded', 'Blinded'],
#  'complexion': ['And'],
#  'catching': ['up', 'a'],
#  'Ring': ['out', 'out', 'out', 'out'],
#  'dislogic': ['and', 'and'],
#  'LOST': ['SOULS', 'AND'],
#  'value': ['of', 'in', 'in', 'in', 'in', 'in'],
#  'ferris': ['wheel,', 'wheel,'],
#  'learn': ['to', 'to', 'something', 'When', 'What', 'When', 'how'],
#  'wartime': ['lie.'],
#  'spirit': ['of', 'seems'],
#  'testing': ['my'],
#  'rottenness': ['and'],
#  "Takin'": ['back', 'back', 'off', 'off', 'off', 'off', 'off', 'off'],
#  'gimme': ['gimme', 'revolution', 'one'],
#  'eyes?': ['And'],
#  'Raise': ['your', 'your'],
#  'strings': ['You'],
#  'Half': ['a', 'a', 'a', 'a'],
#  'pulse': ['is', 'is', 'is', 'of'],
#  'wall/and': ['just'],
#  'RETARDED': ['AND', 'AND'],
#  'photographs.': ['She', 'She'],
#  'dry': ['My', 'My', 'My', 'My', 'My', 'My', 'the', 'the', 'women', 'your'],
#  'Deep': ['inside'],
#  "me/doesn't": ['mean'],
#  'brink': ['of', 'of', 'of', 'Of', 'Of', 'of'],
#  'sugar': ['town'],
#  'thieves': ["I'm"],
#  'as': ['the',
#   'one',
#   'one',
#   'one',
#   'far',
#   'I',
#   'a',
#   'a',
#   'long',
#   'there',
#   "it's",
#   'the',
#   'I',
#   'the',
#   'long',
#   'heroes',
#   'heroes',
#   'if',
#   'a',
#   'a',
#   'a',
#   'much',
#   'perfect',
#   'they',
#   'well',
#   'well',
#   'my',
#   'my',
#   'I',
#   'I',
#   'I',
#   'your',
#   'I',
#   'if',
#   'I',
#   'I',
#   'I',
#   'hell',
#   'long',
#   'it',
#   'long',
#   'it',
#   'long',
#   'it',
#   'much',
#   'I',
#   'my',
#   'well',
#   'minds',
#   'the',
#   "they'll",
#   "they'll",
#   'I',
#   'means',
#   'hell,',
#   'far',
#   'we',
#   'far',
#   'we',
#   'far',
#   'we',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'soon',
#   'my',
#   "you're",
#   'far',
#   'I',
#   'you'],
#  'Time': ['flies',
#   'grabs',
#   'grabs',
#   'grabs',
#   'grabs',
#   'grabs',
#   'stands',
#   'grabs',
#   'grabs'],
#  'trigger': ['from'],
#  'normal': ['and'],
#  'Hell,': ['who'],
#  'not,': ['I'],
#  'STOP': ['IS', 'IS'],
#  'cheaper': ['suit'],
#  'hours,': ["I'll"],
#  'Chinese': ['company', 'company', 'company'],
#  'included': ['<N>'],
#  '(maybe,': ["you're", "you're", "you're"],
#  'world...': ['<N>', '<N>'],
#  'now?': ['Where', '<END>', 'Until', 'Until', 'Until', 'When', '<N>'],
#  'Cola': ['execution'],
#  'memories': ['and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'on',
#   'on',
#   'And',
#   'And',
#   'And'],
#  'sky': ['is',
#   'Now',
#   "Flyin'",
#   'Flying',
#   'is',
#   'is',
#   'That',
#   'Floating',
#   'That',
#   '<N>',
#   '<N>',
#   'is'],
#  'overwhelming': ['Give', 'Give'],
#  'Unless': ['you', 'you', 'you', "you've", "you're", "you're"],
#  'contempt': ['<N>'],
#  'full-throttle': ['screaming'],
#  'forgot': ['<N>', '<N>'],
#  "Jimmy's": ['coming'],
#  'stands': ['and', 'still', 'in'],
#  'date': ['A', 'a', 'Rapidly'],
#  "Shoot'em": ['in', 'in'],
#  'corner': ["Don't", 'for', 'for', 'for', 'for', 'playing', 'of', 'of'],
#  '1:Greenday(Band)]': ['My'],
#  "There'll": ['be'],
#  "hell's": ['your', 'your'],
#  'prepare': ['for'],
#  '[I.': ['Her'],
#  'twisted': ['and'],
#  'Desperate': ['But', 'But', 'But', 'But', 'But', 'But', 'But', 'But'],
#  'already': ['ripped',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'heard',
#   'cut',
#   'had',
#   'had'],
#  'imbecile': ['But'],
#  '4': ['am'],
#  'catch': ['the', 'you', 'twenty'],
#  'Voyage': ['Farewell,'],
#  'business': ['sale'],
#  'Left': ['on', 'on', 'me', 'me', 'me', 'dead'],
#  'nerve': ['Everything', "It's"],
#  'thief': ['<N>', "What's"],
#  'Breeding': ['a', 'a'],
#  "LIVIN'": ['IN'],
#  "it's": ['what',
#   'not',
#   'time',
#   '99',
#   'creating',
#   'sung',
#   'written',
#   'what',
#   'lack',
#   'bringing',
#   'enough',
#   'so',
#   'what',
#   'only',
#   'home',
#   'home',
#   'Sunday',
#   'all',
#   'all',
#   'all',
#   'running',
#   'pouring',
#   'home,',
#   'home',
#   'home,',
#   'home',
#   'just',
#   'just',
#   'non-denominational',
#   'true',
#   'not',
#   'all',
#   'been',
#   'all',
#   'been',
#   'your',
#   'your',
#   'your',
#   'fair',
#   'your',
#   'fuck',
#   'fuck',
#   'fuck',
#   'fuck',
#   'rotting',
#   'better',
#   'not',
#   'not',
#   'not',
#   'worth',
#   'worth,',
#   'right',
#   'worth',
#   'right',
#   'right',
#   'right',
#   'right.',
#   'worth',
#   'right.',
#   'right.',
#   'right.',
#   'right',
#   'worth',
#   'right',
#   'right',
#   'right',
#   'you',
#   'you',
#   'so',
#   'too',
#   'too',
#   'nothing',
#   'nothing',
#   'nothing',
#   'nothing',
#   'nothing',
#   'nothing',
#   'nothing',
#   'nothing',
#   'going',
#   'my',
#   'your',
#   'home',
#   'fuck',
#   'fuck',
#   'fuck',
#   'fuck',
#   'alright',
#   'alright',
#   'alright',
#   'alright',
#   'alright',
#   'alright',
#   'all',
#   'how',
#   'all',
#   'how',
#   'all',
#   'how',
#   'alright',
#   'alright',
#   'alright',
#   'alright',
#   'alright',
#   'alright',
#   'all',
#   'rubbing',
#   'all',
#   'brawn',
#   'all',
#   'do',
#   'too',
#   'too',
#   'too',
#   'too',
#   'too',
#   'just',
#   'not',
#   'gonna',
#   'not',
#   'what',
#   'not',
#   'only',
#   'the',
#   'coming',
#   'a',
#   'the',
#   'the',
#   'raining',
#   'been',
#   'been',
#   'not',
#   'just',
#   'time',
#   'just',
#   'just',
#   'just',
#   'time',
#   'just',
#   'just',
#   'just',
#   'a',
#   'a',
#   'not',
#   'not',
#   'not',
#   'gone',
#   'all',
#   'all',
#   'all',
#   'alright?',
#   'dead',
#   'alright',
#   'the',
#   'the',
#   'the',
#   'more',
#   'like',
#   'all',
#   'my',
#   'my',
#   'my',
#   'the',
#   'the',
#   'right',
#   'worth',
#   'right',
#   'right',
#   'right',
#   'right',
#   'worth',
#   'right',
#   'right',
#   'right',
#   'better',
#   'too',
#   'not',
#   'really',
#   'time',
#   'not',
#   'really',
#   'time',
#   'going',
#   'now',
#   'now',
#   'me',
#   'just',
#   'time',
#   "'cause",
#   'right',
#   'right',
#   'gone',
#   'gone',
#   'so',
#   'so'],
#  'warning': ['you',
#   'I',
#   'Without,',
#   'I',
#   'I',
#   'I',
#   'Without',
#   'I',
#   'I',
#   'I',
#   '<N>'],
#  'alcoholic': ['at'],
#  'conscience': ['beating', "beatin'", "beatin'", 'bleeding'],
#  'descent,': ['your', 'your'],
#  'TALKING': ['TO'],
#  'curves': ['of'],
#  'pussies': ['fight'],
#  'dream,': ['America,'],
#  'Sign': ['my'],
#  'talk': ['you', 'to'],
#  'includes': ['you?'],
#  'became': ['It'],
#  'Missing': ['link', 'link'],
#  'known,': ['right'],
#  'nigh': ['on', 'on'],
#  'Overthrow': ['the', 'the'],
#  'disease': ["It's", 'leave'],
#  "let's": ['have', 'have', 'go', 'go', 'go.'],
#  'cant': ['define', 'have', 'have', 'budge', 'budge'],
#  'pulled': ['the'],
#  'distance': ['I', 'but', 'is'],
#  'Stuart': ['and'],
#  'diabolic': ['state'],
#  'Gone]': ['<N>'],
#  'crack': ['of', 'your'],
#  'sun': ['is',
#   '<N>',
#   'went',
#   'beats',
#   'I',
#   'I',
#   'go',
#   'begins',
#   'Or',
#   "It's",
#   'burn',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is'],
#  '"For': ['crying'],
#  'sunrise': ['Lookout'],
#  'vendetta': ['alive', 'This', 'This'],
#  'setting': ['sun,', 'sun,', 'in', 'fire', 'fire'],
#  'Ever': ['tell'],
#  'Welcome': ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'crap': ["'cause", 'we'],
#  'Where': ['I',
#   'did',
#   'the',
#   'everything',
#   'everything',
#   'everything',
#   'my',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   "I'm",
#   "I'm",
#   "I'm",
#   'did',
#   "you've",
#   "you've",
#   'the',
#   'the',
#   'lived',
#   'are',
#   'are',
#   'have',
#   'have',
#   'will',
#   'did',
#   'have',
#   'is',
#   'did',
#   'did',
#   'did',
#   "dignity's",
#   'can',
#   "there's",
#   'the',
#   'the',
#   'the',
#   'then',
#   'in',
#   'in',
#   "I'm",
#   'have',
#   'have',
#   'have',
#   'do',
#   'do'],
#  'Lazy': ['days', 'days....with'],
#  'marry': ['old', 'old', 'oh,'],
#  'natural': ['disaster', 'disaster,', 'disaster,'],
#  'TOO': ['OLD', 'YOUNG'],
#  'sickie': ['Guess', 'Guess'],
#  'laughing?': ["It's"],
#  'drowning': ['but', 'sorrow'],
#  'fairy': ['tales'],
#  'face': ['You',
#   'I',
#   'is',
#   'A',
#   'is',
#   'is',
#   'A',
#   'is',
#   'is',
#   'A',
#   'is',
#   '<N>',
#   'Magic',
#   'Leaving',
#   'Leaving',
#   'Oh,',
#   "I've",
#   "I've",
#   'The',
#   'I',
#   'The',
#   'I',
#   'Got',
#   '<N>',
#   '<N>',
#   '<END>',
#   "Don't",
#   "Don't",
#   "Don't",
#   "Don't",
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'the',
#   'Got',
#   'the',
#   "You're",
#   "Life's",
#   "Life's",
#   "Life's",
#   'in',
#   '<N>',
#   'and',
#   'and',
#   'and',
#   'and',
#   'down',
#   'down',
#   'but',
#   'but',
#   'but',
#   'but',
#   'You',
#   'of',
#   'in',
#   'in',
#   'in'],
#  'circle': ["'til"],
#  '&amp;': ['violence',
#   'science,',
#   'violence',
#   'science,',
#   'violence',
#   'science,',
#   'violence',
#   'science,',
#   'violence',
#   'science,'],
#  'floor"': ['<N>', '<N>'],
#  'guns': ['Lay',
#   'Throw',
#   'Lay',
#   'Throw',
#   'Lay',
#   'Throw',
#   'Lay',
#   'Throw',
#   'are',
#   'are',
#   'are'],
#  'trunk': ['It'],
#  'again.': ['<N>'],
#  'rebel,': ["she's", "she's"],
#  'Il': ['get'],
#  'forgiven,': ['you', 'you'],
#  'dive': ['<N>'],
#  'ha,': ['ha', 'ha', 'ha', 'ha'],
#  'Try': ['to', 'to', 'to'],
#  'Brown-eyed': ['girl'],
#  'hot': ['these', 'these', 'sun', 'sun', 'as'],
#  'swear': ['to', 'to'],
#  'JULIANA': ['HOMICIDE', 'HOMICIDE', 'HOMICIDE', 'HOMICIDE', 'WALKS'],
#  'figured': ['out', 'out', 'out', 'out', 'out', 'out', 'out', 'out', 'out'],
#  'Praying': ['that', 'that'],
#  'hate.': ['Or'],
#  '[Travis]': ['Every'],
#  'kind': ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   "We'll",
#   "We'll",
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   '<N>',
#   '<N>',
#   'of',
#   'of',
#   'of'],
#  'Holiday': ['-', '-', '-', '-', '<END>', '<END>'],
#  "hitchin'": ['a', 'a'],
#  'paint': ['the', 'the', 'the'],
#  'quo': ['<N>'],
#  'man,': ['egocentric', 'And'],
#  'please.': ['Put', 'Put', 'Put'],
#  'path.': ['I', 'I'],
#  'that...': ['I', "You're"],
#  'adore?': ['<N>', '<N>', '<N>', '<N>'],
#  'own...here': ['we', 'we', 'we'],
#  'clock': ['tick',
#   'tick',
#   'is',
#   'is',
#   'is',
#   'tick',
#   'says',
#   'strikes',
#   'strikes',
#   'strikes',
#   'strikes'],
#  'loneliness': ['has'],
#  'goodbye?': ['The', 'The'],
#  'Billie': ['Joe', 'Joe:', 'Joes'],
#  'Corners': ['of'],
#  'trail': ['now'],
#  'disaster': ['And', 'This', 'Once'],
#  'Always': ['follow',
#   'follow',
#   'move',
#   'move',
#   'move',
#   'fuck,',
#   "fuckin'",
#   'follow'],
#  'open': ['air',
#   'all',
#   'Till',
#   'road',
#   'the',
#   'wide',
#   'the',
#   'up',
#   'No',
#   'No',
#   'No',
#   'wounds',
#   'wounds'],
#  "i've": ['said'],
#  'crowded': ['rooms', 'with'],
#  "Someone's": ['gonna'],
#  'DIED': ['TODAY', 'OF'],
#  "a'la": ['madness'],
#  'courage': ['to', 'to', 'in'],
#  'say': ['goodnight',
#   'that',
#   'that',
#   'my',
#   'woah',
#   'to',
#   '<N>',
#   '<N>',
#   'much',
#   'my',
#   'you',
#   'you',
#   'it',
#   'no?',
#   '<N>',
#   '<N>',
#   "You're",
#   '<N>',
#   '<N>',
#   '<N>',
#   "You're",
#   '<N>',
#   'yeah',
#   'yeah',
#   'Soon',
#   'oh',
#   'one,',
#   'Shit',
#   'yeah',
#   'yeah',
#   'Is',
#   'Is',
#   'Is',
#   'much',
#   'much',
#   'much',
#   'Oh',
#   'I',
#   'to',
#   'making',
#   'it',
#   'We',
#   'sweet',
#   'sweet',
#   '<N>',
#   "'Cause",
#   "'Cause",
#   'you',
#   'And',
#   'And',
#   'And',
#   'And',
#   'And',
#   'goodnight',
#   'it',
#   'you',
#   '(Shout)',
#   'you',
#   '(Shout)',
#   'that',
#   'it',
#   'goodbye',
#   'goodbye',
#   'goodbye',
#   'goodbye',
#   'your',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'no',
#   'Struggle',
#   'shut',
#   'shut',
#   "I'm",
#   'hello',
#   'hello',
#   'not',
#   'Talk',
#   'not',
#   'Talk',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'I',
#   "What's",
#   "There's",
#   "There's",
#   "There's",
#   '<N>',
#   'just',
#   'just'],
#  'self': ['destruct',
#   'destruct',
#   'destruction',
#   'control',
#   'control',
#   'control',
#   'destruction',
#   'control',
#   'control'],
#  'infiltrate': ['the', 'the', 'the'],
#  'He': ['was',
#   'was',
#   'told',
#   "ain't",
#   'said',
#   'lacks',
#   'steals',
#   'hit',
#   'makes',
#   'makes',
#   'makes',
#   'makes',
#   'says,',
#   'blew',
#   'says',
#   'blew',
#   "didn't",
#   'thought',
#   'never',
#   'use',
#   'thinks',
#   'thinks',
#   'fell',
#   'liquidated',
#   'ran',
#   'lives',
#   'makes',
#   'makes',
#   'makes',
#   'makes'],
#  'alert': ['is', 'is', 'is', "You're"],
#  'Fight': ['fire', 'for'],
#  'flower': ['I', 'in'],
#  'worthless': ['pessimist'],
#  'comprehend': ['Things'],
#  '{Verse-2}': ['What'],
#  'fixture': ['on', 'in', 'in', 'in'],
#  'knuckles': ['into', 'into', 'left'],
#  'te': ['da', 'da', 'da', 'da', 'da', 'da'],
#  'Because': ['the',
#   'I',
#   'I',
#   'I',
#   'I',
#   "we're",
#   "we're",
#   "I'll",
#   "I'm",
#   'the',
#   "it's",
#   'I',
#   'I',
#   'I'],
#  'both': ['are', 'knew'],
#  'woman!...Gonna': ['learn'],
#  'nauseous': ['Taken'],
#  'Away': ['from'],
#  'shining': ['bright', 'like', 'lights', 'On', 'I', 'I', 'I'],
#  'younger': ['as', 'I', 'I'],
#  'salmonella': ['poison', 'poison'],
#  'deadline': ['<N>', '<N>'],
#  'meth': ['Like'],
#  'Meet': ['me', 'me', 'me', 'me'],
#  'darkness': ['falls'],
#  'Sha,': ['la', 'la', 'la', 'la', 'la', 'la'],
#  'Counting': ['all'],
#  "gettin'": ['any', 'burned'],
#  'parents': ['told', 'told'],
#  'One': ['thousand',
#   'thousand',
#   'nation',
#   'Two',
#   'nation',
#   'light,',
#   'light,',
#   'hand',
#   'night',
#   'last',
#   'more',
#   'more'],
#  'on....': ['<END>'],
#  'paranoia': ['<N>', "Everybody's"],
#  'surface': ["Don't", 'In'],
#  'imagined': ['<N>', '<N>'],
#  'engagement': ['with'],
#  'LIGHTS': ["'CAUSE"],
#  'Under': ['the', 'the', 'my'],
#  'transistor': ['radio'],
#  'Expiration': ['date,', 'date,'],
#  'gotta': ['do',
#   'do',
#   'do',
#   'get',
#   'get',
#   'live',
#   'live',
#   'live',
#   'live',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'let',
#   'let',
#   'let',
#   'push',
#   'do',
#   'do',
#   'do',
#   'do',
#   'get',
#   'get',
#   'get',
#   'get',
#   'put',
#   'problem'],
#  'fell': ['for',
#   'for',
#   'for',
#   'asleep',
#   'asleep',
#   'victim',
#   'for',
#   'into',
#   'into',
#   'asleep',
#   '<N>'],
#  'persevere': ['As'],
#  'airwaves': ['Another',
#   'Another',
#   'Another',
#   'Another',
#   'Another',
#   'Another',
#   'Slogans'],
#  'fighting': ['for,'],
#  'loved': ['you', 'before', 'I', 'I', 'you'],
#  'Cloaked': ['with'],
#  'repulsive': ['that'],
#  'flagpole': ['and'],
#  'hole': ['Struck', 'Struck', "There's", "There's"],
#  'Jimmy)': ["I'm", '<N>', 'Welcome', '<N>'],
#  'output': ['For'],
#  'hood': ['of'],
#  'tales': ['In'],
#  'finish': ['your', 'last', 'last', 'last', 'last', 'last', 'last'],
#  'count': ['of', 'of', 'the'],
#  'DE': ['THE', 'THE'],
#  'damned': ['<N>',
#   '<N>',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'thing',
#   'Lost',
#   'Lost',
#   'Lost',
#   'Lost',
#   'Lost',
#   'Lost',
#   'to'],
#  'Passionate': ['love', 'love', 'love'],
#  'morning': ['fog', 'your', 'your'],
#  'Starlit': ['night'],
#  'hands,': ['Instead'],
#  'laid,': ["he's"],
#  'stalks': ['his', 'his', 'his'],
#  'tend': ['to'],
#  'venus': ['All', 'All', 'All'],
#  'steals': ['the'],
#  'riding': ['her'],
#  'Having': ['fun'],
#  'staying': ['hungry'],
#  'LONG': ['LOST'],
#  'nine': ['to', 'years'],
#  'bathroom': ['stall', 'stall', 'stall', 'stall', 'stall', 'stall', 'And'],
#  'saints': ['of',
#   'of',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'Of'],
#  'Dreaming': ['I', 'I', 'of', 'of', 'of'],
#  "father's": ['rage', 'come', 'come', 'come'],
#  'deceive': ['me?'],
#  'home': ['in',
#   'We',
#   'yesterday',
#   'yesterday',
#   "We'll",
#   "We'll",
#   '<N>',
#   "We'll",
#   "We'll",
#   '<N>',
#   'Soon',
#   'Soon',
#   '<N>',
#   '<N>',
#   'Soon',
#   '...',
#   'in',
#   'to',
#   'to',
#   'The',
#   'Take',
#   'Take',
#   "It's",
#   '<END>',
#   'I',
#   'is',
#   'But',
#   'I',
#   'I',
#   'Take',
#   '<N>',
#   'I',
#   'I',
#   'Take',
#   '<N>',
#   'I',
#   'I',
#   'Take',
#   'I',
#   'I',
#   'Take',
#   'is',
#   '<N>',
#   '<N>',
#   '<N>',
#   'all',
#   'is',
#   '<N>',
#   '<N>',
#   'My',
#   'My',
#   '<N>',
#   '<N>',
#   '<END>',
#   'When',
#   'When',
#   'Like',
#   'When',
#   'When',
#   'Like',
#   '<END>',
#   'Waste',
#   'After',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'Waste',
#   'After',
#   'again]',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'to',
#   'is',
#   '<N>',
#   'is',
#   '<N>',
#   'is',
#   '<N>',
#   'but',
#   'Where',
#   'After',
#   '<END>',
#   'I',
#   'I',
#   'it',
#   'it',
#   'So',
#   '<N>',
#   'to',
#   '<N>',
#   '<END>',
#   'waste',
#   'Well',
#   'The',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'This',
#   'Welcome',
#   'And',
#   'Welcome',
#   'It',
#   'And',
#   'Welcome',
#   'and',
#   'When',
#   'When',
#   'Like',
#   '<END>'],
#  'kids': ['are',
#   'are',
#   'of',
#   'of',
#   'of',
#   'of',
#   'from',
#   'among',
#   'alright,',
#   'alright,',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are'],
#  'snakes': ['Mistakes'],
#  'test!': ['As'],
#  'desert': ['Reaching'],
#  'now': ['these',
#   'I',
#   'fall',
#   'these',
#   'at',
#   'at',
#   'at',
#   'at',
#   'it',
#   "It's",
#   '<N>',
#   'your',
#   'your',
#   'its',
#   'I',
#   'you',
#   '<N>',
#   'you',
#   'you',
#   'I',
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   'Trust',
#   '<N>',
#   '<N>',
#   'you',
#   'unknown',
#   'unknown',
#   "you're",
#   "you're",
#   "you're",
#   "you're",
#   '<N>',
#   'unfolded',
#   '<N>',
#   '<N>',
#   "She's",
#   "She's",
#   '<END>',
#   'More',
#   'to',
#   'I',
#   'I',
#   'I',
#   'for',
#   'to',
#   'for',
#   'to',
#   'for',
#   'to',
#   'for',
#   'to',
#   'for',
#   'to',
#   'for',
#   'to',
#   'you',
#   'sailing',
#   'sailing',
#   'I',
#   'I',
#   "you're",
#   "you're",
#   'is',
#   'that',
#   'that',
#   '<N>',
#   'I`m',
#   'I`m',
#   'Im',
#   "I'm",
#   "he's",
#   "he's",
#   "he's",
#   "he's",
#   'At',
#   "He's",
#   'Like',
#   "'Cuz",
#   'I',
#   'Right!',
#   'Go-carts',
#   'At',
#   "He's",
#   'I',
#   'This',
#   'Go-carts',
#   '<N>',
#   '<N>',
#   '<N>',
#   '<N>',
#   'at',
#   "he's",
#   'I',
#   'I',
#   "he's",
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   "he's",
#   'I',
#   'I',
#   'my',
#   '(x3)',
#   'in',
#   'we',
#   "you're",
#   'Well',
#   'Well',
#   "you're",
#   "We're",
#   'I',
#   'I',
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   'The',
#   'once',
#   'the',
#   'the',
#   '<N>',
#   "she's",
#   "she's",
#   'it',
#   'and',
#   'That',
#   'Is',
#   'That',
#   'That',
#   "I'm",
#   'the',
#   'I',
#   'your',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'it',
#   'and',
#   'and',
#   'it',
#   'and',
#   'and',
#   'youre',
#   'you',
#   'you',
#   'you',
#   'you',
#   '(Shout)',
#   'that',
#   "You've",
#   '(Shout)',
#   '(Shout)',
#   '(Shout)',
#   '(Shout)',
#   '<N>',
#   '<N>',
#   '<N>',
#   'A',
#   'Jump',
#   'A',
#   'Come',
#   '(Shout',
#   '(Shout',
#   '(Shout',
#   'A',
#   'Jump',
#   'A',
#   'Jump',
#   'A',
#   'Jump',
#   'A',
#   'you',
#   "I'm",
#   "I'm",
#   "I'm",
#   'a',
#   "I'm",
#   "I'm",
#   "it's",
#   "it's",
#   "it's",
#   'From',
#   'been',
#   'we',
#   "I'm",
#   "I'm",
#   'her',
#   "you're",
#   'it',
#   "you're",
#   'it',
#   "you're",
#   'it',
#   "you're",
#   'it',
#   "you're",
#   'it',
#   "you're",
#   'it',
#   'till',
#   'And',
#   'Go-carts',
#   'it',
#   'Feeling',
#   'Feeling',
#   "he's",
#   "he's",
#   "he's",
#   "he's",
#   '<N>',
#   '<N>',
#   '<N>',
#   '<N>',
#   '<N>',
#   '<END>',
#   "it's",
#   'I',
#   "it's",
#   'Can',
#   "she's",
#   'sailing'],
#  'pray': ["There's", "There's", "There's", "There's", "There's", 'all'],
#  'surreal': ['Lay', 'Lay', 'Lay'],
#  'you)': ['This'],
#  'Tight': ['Wad', 'Wad', 'Wad', 'Wad', 'Wad', 'Wad'],
#  'due': ['home', 'home', 'to'],
#  'lightning': ['Before', 'Before', '<N>', '<N>', 'Oh,'],
#  'anymore': ['<N>',
#   'What',
#   '<N>',
#   'What',
#   '<N>',
#   '<N>',
#   '<END>',
#   'But',
#   '<N>',
#   '<N>',
#   '<END>',
#   'ause'],
#  'stream': ['And', 'And', 'And', 'And', 'And', 'And', 'of'],
#  'Toxin': ['your'],
#  'hes': ['says'],
#  'bishop': ['is'],
#  'Lost': ['and',
#   'and',
#   'and',
#   'and',
#   'children',
#   'children',
#   'children',
#   'children',
#   'children',
#   'children',
#   'children',
#   'children',
#   'my',
#   'regrets'],
#  'people.': ['Fight'],
#  'NO': ['ONE', 'SCREAM', 'ONE', 'SCREAM'],
#  'three': ['times', 'times', 'whole'],
#  'bike': ['like'],
#  'lazy': ['Or',
#   'three',
#   "There's",
#   "There's",
#   "There's",
#   "There's",
#   '<N>',
#   'But',
#   'But',
#   'stupid',
#   "There's",
#   "There's",
#   "There's",
#   "There's"],
#  'Old': ['toys,', 'story,', 'days', 'days'],
#  'once': ['we',
#   'was',
#   'was',
#   'did',
#   'I',
#   'filled',
#   'filled',
#   'filled',
#   'again',
#   'again',
#   'again',
#   'again?',
#   'again',
#   'in',
#   'in',
#   'again,',
#   'well,',
#   'again',
#   'again',
#   'Intoxications',
#   'too',
#   'too',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again'],
#  'has': ['died',
#   'got',
#   'got',
#   'got',
#   'rained',
#   'now',
#   'fallen',
#   'been',
#   'been',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'gone',
#   'crossed',
#   'the',
#   'crossed',
#   'the',
#   'come',
#   'come',
#   'been',
#   'to',
#   'got',
#   'now',
#   'come',
#   'gone',
#   'come',
#   'come',
#   'gone',
#   'come',
#   'gone',
#   'come',
#   'come',
#   'gone',
#   'come',
#   'gone',
#   'come',
#   'come',
#   'gone',
#   'been.',
#   'been.',
#   'come',
#   'left',
#   'been',
#   'been',
#   'been',
#   'been',
#   'turned',
#   'pierced'],
#  'innocent': ['can', 'can', 'can', 'can', 'can', 'can', 'can', 'can', 'can'],
#  'Oh,': ['so',
#   'well',
#   'well',
#   'hand',
#   'hand',
#   "I'll",
#   "I'm",
#   "I'll",
#   'you',
#   "don't",
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   "isn't",
#   'but',
#   'but',
#   'the',
#   'your',
#   'I',
#   'if',
#   'ho',
#   'ho',
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   'yeah',
#   "I'm",
#   "I'm",
#   "I'm",
#   'now',
#   'now',
#   'you',
#   'I',
#   'I',
#   "I'll",
#   'can',
#   'can',
#   'can',
#   'can',
#   'oh',
#   'oh',
#   'oh',
#   'oh',
#   'no',
#   "it's",
#   'maby,',
#   'the',
#   'the',
#   'is',
#   'where',
#   'where'],
#  'Any': ["you're"],
#  'too,': ['I', 'and'],
#  'effigy': ['The', 'The'],
#  'threat': ['Is'],
#  'coffee': ['with', 'with', 'with', 'and', 'with', 'And', "I'm", 'and', 'im'],
#  'hunger': ['strike'],
#  'Question': ['everything', 'everything'],
#  'asked': ['you', 'about', 'for', 'for', 'about'],
#  '(Give': ['up)'],
#  'stone': ['<N>', 'Cross', 'and', 'The'],
#  'bleed': ['Dried',
#   'Dried',
#   '<N>',
#   'Dried',
#   'Dried',
#   'Dried',
#   'Dried',
#   'Tears',
#   'Tears',
#   'now',
#   'now',
#   'now',
#   'now',
#   'now',
#   'now',
#   "I'm",
#   "I'm"],
#  'sin,': ['to', 'to'],
#  "SHOUTING'S": ['OVER',
#   'OVER',
#   'OVER',
#   'OVER',
#   'OVER',
#   'OVER',
#   'OVER',
#   'OVER'],
#  'name.': ['Now', 'Now'],
#  'Ivor': ['the', 'The', "I'm", 'the'],
#  'Skinhead': ['gangs'],
#  'field': ['I', 'I'],
#  'Eiffel': ['Tower', 'towers', 'towers'],
#  'Please': ['take',
#   'call',
#   'call',
#   'leave',
#   "don't",
#   "don't",
#   "don't",
#   "don't",
#   "don't",
#   "don't",
#   "don't",
#   "don't"],
#  'violence': ['English,', 'English,', 'English,', 'English,', 'English,'],
#  'PIECES': ['ON'],
#  'Slugs': ['and'],
#  'defiance': ["I'll"],
#  'repercussions': ['Headaches', 'Headaches'],
#  'ditching': ['me'],
#  'chemical': ['emotions', 'emotions', 'reaction'],
#  'hounds': ['on'],
#  'beat,': ['the'],
#  "ain't": ['here',
#   'here',
#   'no',
#   'either',
#   'no',
#   'either',
#   'no',
#   'no',
#   'for',
#   'for',
#   'so',
#   'for',
#   'for',
#   'nowhere',
#   'nowhere',
#   'nowhere',
#   'a',
#   'worth',
#   'no',
#   'got',
#   'nowhere',
#   'enough',
#   'what',
#   'right',
#   'right',
#   'got',
#   'got',
#   'got'],
#  'Ah,': ['ha', 'ha'],
#  'circus': ['And', 'from'],
#  'loud,': ['all'],
#  'better?': ['<N>'],
#  'hands': ['flow',
#   'flow',
#   'flow',
#   'And',
#   'of',
#   'now',
#   'all',
#   "You're",
#   'and',
#   'of',
#   'up',
#   'of',
#   'of',
#   'of'],
#  'Forgiven]': ['<N>'],
#  'restless': ['soul', 'soul', 'soul'],
#  "She'll": ['drag'],
#  'sing': ['along', 'you', 'for', 'for', 'With', 'and', 'and'],
#  'bank': ['robber'],
#  'Caution:': ['police', 'police'],
#  'hooch': ['Why'],
#  'Spike': ['TV', 'T.V'],
#  'down?)': ['<N>'],
#  'facility': ['on', 'on', 'on', 'on'],
#  'demonstration': ['Of'],
#  'high': ['definition',
#   'I',
#   'I',
#   'I',
#   '<N>',
#   'On',
#   'But',
#   'On',
#   'But',
#   'On',
#   'But',
#   'On',
#   'On',
#   'But',
#   'On',
#   'But',
#   '<N>',
#   '<N>',
#   'Stick',
#   'rise',
#   'The',
#   'school',
#   'When',
#   'When',
#   'When',
#   'Well,',
#   'Well,',
#   'Shit',
#   'is'],
#  'than': ["I've",
#   'it',
#   'air',
#   'that',
#   'that',
#   'lonely',
#   'lonely',
#   'lonely',
#   'into',
#   'I',
#   'enough',
#   'enough',
#   'that',
#   'that',
#   "I've",
#   'bombs',
#   'the',
#   'to',
#   'to',
#   'I',
#   'I',
#   'I'],
#  'deaf,': ['blind'],
#  'flesh': ['down', 'on', 'turns', 'turns'],
#  'ooo': ['Ooo', '<N>'],
#  'blasphemy': ['and', 'and', 'and'],
#  "who're": ['meant', 'meant', 'meant'],
#  'doped': ['with'],
#  'use': ["Don't", "Don't", 'my', 'to'],
#  'BLUSHING': ['BRIDE', 'BRIDE'],
#  'beloved': ['are', 'are', 'are'],
#  'victim': ['of', 'to', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'Vigilante': ['Missing', 'Missing'],
#  'sent': ['to'],
#  'rank': ['<N>'],
#  'shoulda': ['somehow', 'somehow', 'somehow'],
#  'anybody': ['feels', 'feels', 'wasting'],
#  'weigh': ['out'],
#  'breeding': ['The'],
#  '4:': ['Rock'],
#  'croaked': ['She'],
#  "life's": ['a', 'on', 'on', 'on', 'on'],
#  'Its': ['like', 'been', 'been', 'been', 'the', 'the'],
#  "don't": ['put',
#   'look',
#   'cross',
#   'know',
#   'you',
#   'know',
#   'you',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'give',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'you',
#   'go',
#   'you',
#   'go',
#   'go',
#   'go',
#   'you',
#   'go',
#   'put',
#   'look',
#   'know.',
#   'know.',
#   'dare',
#   'make',
#   'make',
#   'make',
#   'seem',
#   'believe',
#   'believe',
#   'know',
#   'look',
#   'look',
#   'care',
#   'mind',
#   'know',
#   'get',
#   'wanna',
#   'wanna',
#   'have',
#   "Don't",
#   'belong',
#   'call',
#   'call',
#   'leave',
#   'believe',
#   'wanna',
#   'believe',
#   'wanna',
#   'wanna',
#   'wanna',
#   'wanna',
#   'believe',
#   'believe',
#   'want',
#   'want',
#   'ask',
#   'ask',
#   'ask',
#   'ask',
#   'ask',
#   'know',
#   'care',
#   'care',
#   'agree',
#   'agree',
#   'want',
#   'want',
#   'you',
#   'care',
#   'I',
#   'care',
#   '<N>',
#   'care',
#   'care',
#   'care',
#   'care',
#   'care',
#   'care',
#   'care',
#   'care',
#   'care',
#   'believe',
#   'believe',
#   'care',
#   'care',
#   'care',
#   'care',
#   'care',
#   'want',
#   'wanna',
#   'want',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'want',
#   'think',
#   'want',
#   'you',
#   'think',
#   'want',
#   'you',
#   'think',
#   'want',
#   'you',
#   'let',
#   'let',
#   'let',
#   'think',
#   'think',
#   'want',
#   'want',
#   'mind',
#   'mind',
#   'care,',
#   'care',
#   'mind',
#   'mind',
#   'want',
#   'wanna',
#   'wanna',
#   'believe',
#   'believe',
#   'care',
#   'I',
#   'care',
#   'I',
#   'care',
#   'care',
#   'care',
#   'believe',
#   'believe',
#   'care!',
#   'exist',
#   'feel',
#   'believe',
#   'believe',
#   'care',
#   'I',
#   'care',
#   'I',
#   'care',
#   'care',
#   'care',
#   'believe',
#   'believe',
#   'care!',
#   'exist',
#   'feel',
#   'believe',
#   'believe',
#   'care',
#   'I',
#   'care',
#   'I',
#   'care',
#   'care',
#   'care',
#   'believe',
#   'believe',
#   'care!',
#   'exist',
#   'feel',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   "don't",
#   'know',
#   'know',
#   'know',
#   'know',
#   "don't",
#   'know',
#   'know',
#   'wanna',
#   'want',
#   'wanna',
#   'want',
#   'want',
#   'wanna',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'give',
#   'give',
#   'give',
#   'even',
#   'look',
#   'bite',
#   'you',
#   'like',
#   'belong',
#   'belong',
#   'belong',
#   'belong',
#   'need',
#   'need',
#   'need',
#   'need',
#   'know',
#   'know',
#   'know',
#   'you',
#   'try',
#   'you',
#   'try',
#   'be',
#   'you',
#   'want',
#   'pass',
#   'stop',
#   'know,',
#   'seem',
#   'have',
#   'have',
#   'care',
#   'care',
#   'even',
#   'look',
#   'care',
#   'care',
#   'care',
#   'care',
#   'mind',
#   'care',
#   'mind',
#   'care',
#   'mind',
#   'care',
#   'know',
#   'seem',
#   'know',
#   'seem',
#   'let',
#   'know,',
#   'say',
#   'deny',
#   'know,',
#   'say',
#   'know,',
#   'say',
#   'know,',
#   'say',
#   'know,',
#   'say',
#   'even',
#   'even',
#   'wear',
#   'want',
#   'want',
#   'want',
#   'wanna',
#   'want',
#   'know',
#   'wear',
#   'wanna',
#   'wanna',
#   'understand',
#   'wanna',
#   'wanna',
#   'exist',
#   'feel',
#   'look',
#   'look',
#   'feel',
#   'look',
#   'look',
#   'look',
#   'look',
#   'have',
#   'mean',
#   'have',
#   'have',
#   'mean',
#   'mind',
#   'mind,',
#   "I'll",
#   'ask',
#   'ask',
#   'keep',
#   'keep',
#   'keep',
#   'keep',
#   'keep',
#   'keep',
#   'keep',
#   'keep',
#   'let',
#   'get',
#   'get',
#   'knock',
#   'need',
#   'take'],
#  'boyfriend': ['Maybe', 'Maybe', '<N>', 'there?', 'there?'],
#  'Pick': ['myself'],
#  'everyone': ['left', "I've", 'to', 'left'],
#  'structure': ['waving'],
#  "Lovin'": ['every'],
#  'ahead': ['and', 'and', 'and', 'and', 'and', 'and'],
#  'changing': ['the'],
#  "masturbation's": ['lost'],
#  'tattoo': ['a', 'of'],
#  'bout': ['my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my',
#   'my'],
#  'holding': ['on', 'on', 'on'],
#  'commit': ['me', 'the', 'the'],
#  'will': ['testify',
#   'remember',
#   'be',
#   'prove',
#   'I',
#   'I',
#   'be',
#   'testify',
#   'remember',
#   'obey',
#   'obey',
#   'obey',
#   'return',
#   'find',
#   'find',
#   'find',
#   'find',
#   'find',
#   'find',
#   'find',
#   'find',
#   'take',
#   'explode',
#   'earn',
#   'be',
#   'be',
#   'never',
#   'never',
#   'never',
#   'be',
#   'be',
#   'disappear',
#   'be',
#   'be',
#   'dry',
#   'to',
#   'bear',
#   'bear',
#   'find',
#   'be',
#   'he',
#   'that',
#   'get',
#   'get',
#   'get',
#   'be',
#   'rise',
#   'come',
#   'come',
#   'all',
#   'we',
#   'change',
#   'My',
#   'fill',
#   'get',
#   'kill',
#   'try',
#   'try',
#   'think',
#   'divide',
#   'dare',
#   'dare',
#   'dare',
#   'happen',
#   'fight',
#   '(Shout,',
#   '(Shout,',
#   'find',
#   'you',
#   'someday',
#   'suffocate',
#   'someday',
#   'suffocate',
#   'someday',
#   'suffocate',
#   'someday',
#   'suffocate',
#   'always',
#   'always',
#   'always',
#   'always',
#   'always',
#   'always',
#   'be',
#   'be',
#   'to',
#   'to',
#   'be',
#   'bear',
#   'never',
#   'always',
#   'take',
#   'take',
#   'Say'],
#  'overcome': ['thinking'],
#  'visit': ['me', 'me', 'me'],
#  'combustion,': ['panic'],
#  'war': ['Your',
#   'is',
#   'Your',
#   'today',
#   'today',
#   'and',
#   'and',
#   'and',
#   'and',
#   '<N>',
#   '<N>',
#   'to',
#   'and',
#   'and',
#   'and',
#   'We',
#   'and'],
#  'wont': ['apologize', 'apologize', 'apologize', 'be', 'be'],
#  'feel': ['yourself',
#   'all',
#   'blue',
#   'in',
#   'in',
#   'so',
#   'so',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'complete',
#   'as',
#   'pain',
#   'my',
#   'the',
#   'my',
#   'a',
#   'a',
#   'overwhelmed',
#   'any',
#   'any',
#   'any',
#   'so',
#   'so',
#   'so',
#   'so',
#   'the',
#   'washed',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'this',
#   'this',
#   'this',
#   'a',
#   'so',
#   'so',
#   'so',
#   'so',
#   'like',
#   'forgotten',
#   'the',
#   'the',
#   'the',
#   'forgotten',
#   'the',
#   'the',
#   'the',
#   'the',
#   'like',
#   'any',
#   'strange,',
#   'i',
#   'that',
#   "I'm",
#   "I'm",
#   'the',
#   'lonely',
#   'small',
#   'nothing',
#   'like'],
#  'TABLES': ['TURN', 'TURN'],
#  'break': ['your',
#   'through',
#   'through',
#   'through',
#   'You',
#   "You're",
#   'You',
#   "You're",
#   'as',
#   'as',
#   'of',
#   'of',
#   'of',
#   'of',
#   'your',
#   'your',
#   'your',
#   'your',
#   'your',
#   'in',
#   'When',
#   'When',
#   'When',
#   'your',
#   'your',
#   'you',
#   'the',
#   'the',
#   'away.....'],
#  'his': ['own',
#   'own',
#   'mind',
#   'own',
#   'vintage',
#   'name',
#   'face?',
#   'world',
#   'world',
#   'world',
#   'world',
#   'brains',
#   'own',
#   'brains',
#   'own',
#   'life',
#   'life',
#   'life',
#   'life',
#   'life',
#   'guitar',
#   'music',
#   'name',
#   'estate',
#   'face?',
#   'hand',
#   'head',
#   'brains',
#   'will',
#   'prey',
#   'prey',
#   'will',
#   'prey',
#   'life',
#   'existence',
#   'life',
#   'existence',
#   'face?',
#   'own',
#   'face?',
#   'world',
#   'world',
#   'world',
#   'world',
#   'love'],
#  'understands': ['your', 'your'],
#  'us?': ['The'],
#  "nobody's": ['fool.'],
#  'lots': ['more', 'of'],
#  'fate': ['Give', 'Give', 'Give', 'Give', '<N>', 'Or'],
#  'Armstrong]': ['[Originally'],
#  'Dominated': ['by'],
#  'awake': ['After', 'I'],
#  'afar': ['standing', '<N>'],
#  "crawl'!": ['the'],
#  'Queen': ['She',
#   'She',
#   'Is',
#   'Her',
#   'What',
#   'Oh',
#   'You',
#   'Is',
#   'Is',
#   'From',
#   'I',
#   'Is'],
#  'desolation': ['road', 'road', 'road'],
#  'crowd': ['<N>', '<N>', 'of', 'of', 'are', 'Unsung,'],
#  'unknown': ['<N>', '<N>', '<N>', 'Are', '<END>', 'An', 'An', 'An', 'I', 'I'],
#  'scale': ['Prevailing'],
#  'G-L-O-R-I-A!': ['<END>'],
#  'stare': ['<N>'],
#  'salutations': ["You're"],
#  'ride,': ['tell', 'free', 'free'],
#  'Made': ['me'],
#  '(Gloria!)': ['As', 'The', 'As', 'The', "You're"],
#  'honor': ['to', 'you', 'you', 'you'],
#  'coat,': ['you'],
#  'day!': ['<N>', '<N>'],
#  'production': ['line'],
#  'paralyze': ['this'],
#  'paranoid': ['like', 'Music'],
#  'losers': ["Nothing's", "Nothing's", "Nothing's", 'and', 'that'],
#  'scared': ['Strange', 'you'],
#  'toys?': ['I'],
#  'boy,': ["You're", 'come'],
#  'IN': ['CAGES', 'LOVE', 'LOVE', 'THE'],
#  'meet': ['again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'again',
#   'me',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you'],
#  'upon': ['your', 'my', 'my', 'my', 'the'],
#  'due,': ['what', 'what'],
#  'W': ["You're"],
#  'cold.': ["Talkin'"],
#  'Sucked': ['on'],
#  'Brothers]': ['<N>'],
#  'Wide': ['open'],
#  "Isn't": ['it', 'it', 'it', 'it', 'that'],
#  "don't'": ['know'],
#  'Scream': ['and', 'and', 'at', 'at'],
#  'regression': ['The'],
#  'oh,': ["what's", 'Whatshisface', 'you'],
#  'queens': ['and'],
#  'Idle': ['thoughts'],
#  'majority': ['While', "We're", "'Cause", "'Cause", "'Cause", "'Cause"],
#  'awful': ['cold.'],
#  'seasons': ['come'],
#  "Losin'": ['faith', 'health'],
#  'loner': ['in', 'in', 'in', 'in'],
#  'figure': ['out'],
#  '21st': ['century', 'century'],
#  'fuck,': ["fuckin'"],
#  'wishful': ['thinking'],
#  'peace,': ['and'],
#  'punk': ['sees', 'come'],
#  'Everyone': ['left',
#   'left',
#   'left',
#   'left',
#   'left',
#   'keeps',
#   'left',
#   'left',
#   'left'],
#  "Whatever's": ['in'],
#  'Lobotomy!': ['Lobotomy!',
#   'Lobotomy!',
#   'Lobotomy!',
#   '<N>',
#   'Lobotomy!',
#   'Lobotomy!',
#   'Lobotomy!',
#   '<N>'],
#  'surprise': ['Now'],
#  'RIDE!!!': ['<N>', '+8'],
#  'Goode...': ['He'],
#  'shy': ['Am'],
#  'conflict': ['is', 'is', 'is'],
#  'pass': ["Nothing's",
#   "Don't",
#   "Don't",
#   'me',
#   'your',
#   'me',
#   'Seven',
#   'Twenty',
#   'Seven',
#   'Twenty',
#   'Seven',
#   'Twenty',
#   'The'],
#  ',go)': ['<N>'],
#  'tongue.': ['An'],
#  "anyone's": ['last'],
#  'extinction': ['<N>', 'She'],
#  'bullet': ['in', 'that', 'that', 'in'],
#  'ache': ['of'],
#  'tangled': ['mind', 'your', 'at'],
#  'Laughing': ['and'],
#  'cryin\x7fI': ['buyin\x7ffor'],
#  'Caesar': ["I'm"],
#  'Earth': ['with', "I'm", 'And', 'And'],
#  'funky': ['chicken!', 'moves'],
#  'hero': ['<N>',
#   '<N>',
#   'for',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is'],
#  'present': ['now', 'and', 'now', 'and', 'now', 'and'],
#  'You': ['blast',
#   'found',
#   'made',
#   'and',
#   'and',
#   'and',
#   "ain't",
#   'Are',
#   'are',
#   'are',
#   'and',
#   'and',
#   'and',
#   'want',
#   'want',
#   'are',
#   'tangled',
#   'let',
#   'say',
#   'are',
#   'are',
#   'are',
#   'are',
#   'used',
#   'say',
#   'are',
#   'are',
#   'blast',
#   'found',
#   'made',
#   'dug',
#   'dug',
#   'take',
#   'take',
#   'can',
#   'better',
#   'will',
#   'know',
#   'know',
#   'lied',
#   'looked',
#   'cried',
#   'filthy',
#   'dirty',
#   'dirty',
#   'and',
#   'and',
#   'and',
#   'were',
#   'were',
#   'know',
#   'know',
#   'taught',
#   'taught',
#   'keep',
#   'keep',
#   'keep',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'finally',
#   'fell',
#   'bumped',
#   'said',
#   'better',
#   'are',
#   'can',
#   'always',
#   'better',
#   'look',
#   'feel',
#   'might',
#   'lose',
#   'might',
#   'might',
#   'might',
#   'might',
#   'want',
#   'Later',
#   'better',
#   'better',
#   'better',
#   'better',
#   'better',
#   'better',
#   'were',
#   'make',
#   'will',
#   'told',
#   'and',
#   'and',
#   'and',
#   'thought',
#   'better',
#   'know',
#   'know',
#   'place',
#   'know',
#   'name',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'erased',
#   "don't",
#   'have',
#   'can',
#   'have',
#   'can',
#   "don't",
#   "don't",
#   "don't",
#   'never',
#   'are',
#   'are',
#   'are',
#   'are',
#   'would',
#   'would',
#   'would',
#   'come',
#   'never',
#   'wanna',
#   'know',
#   'make',
#   'look',
#   'will',
#   'will',
#   'pushed',
#   'better',
#   'pushed',
#   'better',
#   'must',
#   'know',
#   'change',
#   'must',
#   'bumped',
#   'said,',
#   'start',
#   'tragedy',
#   'start',
#   'may',
#   "can't",
#   'call',
#   'wonder',
#   'find',
#   'got',
#   'Can',
#   'gotta',
#   'lied',
#   'lied,',
#   'dirty'],
#  'avoid': ['the', 'the', 'the'],
#  "autumn's": ['wind', 'wind'],
#  'anymore.': ['<N>'],
#  'there': ['I',
#   'and',
#   'I',
#   'I',
#   'any',
#   'are',
#   'I',
#   'I',
#   'I',
#   "lookin'",
#   "lookin'",
#   'will',
#   'will',
#   'will',
#   'will',
#   'will',
#   'will',
#   'will',
#   'are',
#   'will',
#   'is',
#   'Or',
#   'a',
#   'a',
#   'I',
#   'I',
#   'a',
#   'a',
#   'must',
#   'will',
#   'would',
#   'would',
#   'I',
#   'I',
#   'I',
#   '<N>',
#   'I',
#   'I',
#   'I',
#   '<N>',
#   'I',
#   'I',
#   'I',
#   '<END>',
#   'in',
#   'in',
#   "ain't",
#   "ain't",
#   "ain't",
#   'too,',
#   'goes',
#   'Scream',
#   '<N>',
#   'Scream',
#   '<END>',
#   'is',
#   'something',
#   "I've",
#   "I've",
#   "I've",
#   'Is',
#   'Is',
#   'once',
#   'If',
#   "I'll",
#   'You',
#   'You',
#   "I'll",
#   '<N>',
#   'not',
#   'for',
#   'Amongst',
#   "I'll",
#   '<N>',
#   'not',
#   'for',
#   'To',
#   "I'll",
#   '<N>',
#   'not',
#   'for',
#   'for',
#   'for',
#   'Story',
#   'Story',
#   'Story',
#   "ain't",
#   'she',
#   'At',
#   'on',
#   'You',
#   'and'],
#  'shaking': ['lots'],
#  'composure': ['and'],
#  'directions': ['For', 'and'],
#  'number': ['and'],
#  'stomping': ['ground'],
#  'sport': ['of'],
#  'around,': ['and',
#   'I',
#   "you're",
#   "you'll",
#   "you're",
#   "you'll",
#   "you're",
#   "you're"],
#  'girlfriend': ['and', 'And', 'And', 'is', 'left', 'And', 'left'],
#  '(gloria)': ["You're", "You're"],
#  'times,': ['it'],
#  'out,': ['Drop',
#   'Drop',
#   'Drop',
#   'Drop',
#   'here',
#   'there',
#   'I',
#   'finding',
#   'buried',
#   'buried'],
#  'musician.': ['Whatcha'],
#  'else': ['now,',
#   'now,',
#   'now',
#   'now,',
#   'to',
#   'to',
#   'to',
#   'would',
#   'I',
#   "he's",
#   "you've",
#   'anyway,',
#   'anyway,',
#   'anyway,',
#   '<N>'],
#  'trusted': ['anyone'],
#  'difference': ['but', 'between', 'between'],
#  'employ': ['was'],
#  'house': ['and',
#   'But',
#   'But',
#   'But',
#   'is',
#   'is',
#   'But',
#   'But',
#   'Has',
#   'I',
#   'I',
#   'with',
#   'You',
#   'I',
#   'Wasting',
#   'in'],
#  'sucks': ['to', 'to', 'to', 'to', 'to', 'to'],
#  'jug': ['of', 'of'],
#  'Stepped': ['out'],
#  'seemed': ['to', 'to', 'to', 'to', 'to'],
#  'disaster!': ["I'm", "I'm", "I'm"],
#  'goodbye': ['from',
#   'And',
#   'And',
#   'Until',
#   '<N>',
#   '<N>',
#   '<END>',
#   'Say',
#   '<N>',
#   'Say',
#   '<END>',
#   'and'],
#  'guitar': ['<N>', 'I', 'like', 'in', '<N>'],
#  'moment': ['till', 'trapped', "Don't", "Don't", 'as', 'to', 'to', "Sleazin'"],
#  '(Music': ['to'],
#  'exciting': ['The'],
#  'Hold': ['on', 'on', 'on', 'on', 'him'],
#  'burst': ['in', 'in'],
#  'clout': ['<N>'],
#  'waking': ['moment'],
#  'Whats': ['the'],
#  'determined': ['<N>'],
#  'hustler': ['out'],
#  'OUR': ['SOULS'],
#  'naughty': ['Put', 'I'],
#  'To': ['the',
#   'the',
#   'one',
#   'keep',
#   'analyze',
#   'cast',
#   'the',
#   'a',
#   'the',
#   'know',
#   'drive',
#   'walk',
#   'walk',
#   'walk',
#   'walk',
#   'walk',
#   'the',
#   'the',
#   'the',
#   'anyone',
#   'say',
#   'say',
#   'a',
#   'lead',
#   'me',
#   'me',
#   'me',
#   'me',
#   'me',
#   'me',
#   'me',
#   'me',
#   'reach',
#   'see',
#   'a',
#   'find,',
#   'a',
#   'find,',
#   'send',
#   'the',
#   'hell',
#   'hell',
#   'hell',
#   'know',
#   'this',
#   'know',
#   'fall',
#   'alcohol',
#   'keep',
#   'live,',
#   'run,',
#   'find,',
#   'the',
#   'fall',
#   'alcohol',
#   'keep',
#   'live,',
#   'run,',
#   'find,',
#   'the',
#   'fall',
#   'alcohol',
#   'keep',
#   'live,',
#   'run,',
#   'find,',
#   'the',
#   'hear',
#   'find',
#   'find',
#   'tell',
#   'my',
#   'come',
#   'make',
#   'hell',
#   'make',
#   'make',
#   'make',
#   'a',
#   'this',
#   'this',
#   'this',
#   'see',
#   'kill',
#   'kill',
#   'catch',
#   'Hell',
#   'Hell',
#   'have',
#   'run',
#   'take',
#   'your',
#   'live',
#   'run,',
#   'find',
#   'try',
#   'guide',
#   'throw'],
#  'feets': ['<N>'],
#  'Soda': ['Pop', 'Pop', 'Pop'],
#  'Yaaahhh!!!': ['Ah'],
#  'spring': ['I', 'began', 'began', 'began'],
#  'Her': ["Man's",
#   "man's",
#   "man's",
#   'life',
#   'ex-boy',
#   'black',
#   'mother',
#   'plastic',
#   'eyes'],
#  'rockets': ['and'],
#  'down!"': ['<N>', '<END>'],
#  'skill': ['to'],
#  'know.': ["They're", "They're"],
#  'ENOUGH': ['TO'],
#  'accuser': ['To'],
#  'Emergency': ['evacuation'],
#  'La,': ['la,', 'la,'],
#  'motor': ['in'],
#  'sorrow': ["There's", "There's", 'Because', 'floods'],
#  'understand?': ['Amanda,', 'Amanda,', 'Amanda,'],
#  'gagging': ['on'],
#  ',5,4,3,2,1': ['<END>'],
#  'like/a': ['kiss'],
#  'Dumbstruck': ['Color'],
#  'Making': ['love',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'your',
#   'your',
#   'paper',
#   'paper',
#   'sure',
#   'plans'],
#  'weeks': ['Since'],
#  'rearranged': ['<N>', '(Angel)'],
#  'Now': ["we'll",
#   'all',
#   'everybody',
#   "I'm",
#   'youre',
#   'youre',
#   'youre',
#   'youre',
#   'youre',
#   'live',
#   'live',
#   'I',
#   'I',
#   'I',
#   "it's",
#   "it's",
#   'I',
#   "it's",
#   'that',
#   "I'm",
#   'I',
#   'mom',
#   'mom',
#   'mom',
#   'you',
#   'you',
#   'that',
#   'the',
#   "where's",
#   'are',
#   'Ie',
#   'I',
#   'I',
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   "she's",
#   'you',
#   "he's",
#   "he's",
#   'he',
#   'you',
#   'I',
#   'the',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'that',
#   'I',
#   'I',
#   'I',
#   'I',
#   "I'm",
#   "I'm",
#   'my',
#   'my',
#   'all',
#   'all',
#   'all',
#   'all',
#   'all',
# ...
#   'give',
#   'see',
#   'really',
#   'really',
#   'really',
#   'play',
#   'play',
#   'cry',
#   'cry',
#   'tell',
#   'see',
#   'only',
#   'be',
#   'find',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'have'],
#  'seat': ['and'],
#  'gettin': ['stale'],
#  "'round": ['The', 'for', 'The', 'for', 'The', 'for', 'your', 'this', 'my'],
#  'Good': ['night', 'night', 'luck'],
#  'vain': ['Knocking'],
#  'Expect': ['it', 'it'],
#  'pen': ['is'],
#  'days': ['amongst',
#   'amongst',
#   "They're",
#   'But',
#   'So',
#   "(Don't",
#   'Gone',
#   'And',
#   'And',
#   'And',
#   'are',
#   'go',
#   '<N>',
#   'Youre',
#   'are',
#   'are',
#   "don't",
#   "don't",
#   'have',
#   'Where',
#   'Where',
#   'Where',
#   "we've"],
#  "family's": ['from', 'from'],
#  'APART': ['LIKE'],
#  'Angel': ['Blue',
#   'Blue',
#   'Blue',
#   'Blue',
#   'Blue',
#   'Blue',
#   'dancing',
#   'turning',
#   'and'],
#  'generation,': ['baby.'],
#  'run': ['My',
#   'away,',
#   'away,',
#   'away,',
#   'and',
#   'and',
#   'to',
#   'Well',
#   'Well',
#   'Well',
#   'Well',
#   'around',
#   'around',
#   'around',
#   'around',
#   'around',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'for',
#   'the',
#   'it',
#   'away',
#   'away',
#   'away',
#   'away',
#   'out',
#   '<N>',
#   'away',
#   'away',
#   'away',
#   'and',
#   'away',
#   'and'],
#  'town': ['was',
#   '<N>',
#   'Your',
#   'is',
#   'is',
#   'Ha',
#   'Ha,',
#   'Ha',
#   'Underneath',
#   'Underneath',
#   '<N>',
#   'that',
#   'that',
#   'that',
#   'You',
#   '<N>',
#   'Those',
#   '<N>',
#   '<N>',
#   '<N>',
#   'bishop',
#   "I'm",
#   'is',
#   '(Come',
#   '(Sugar',
#   '<N>',
#   'And',
#   'And',
#   'And',
#   'I',
#   'that',
#   'Underneath',
#   '<N>',
#   'Cause'],
#  'mental': ['stability', 'health', 'health', 'health', 'cave', 'to'],
#  'What': ['brings',
#   'is',
#   'is',
#   'makes',
#   'is',
#   'time?',
#   'is',
#   'is',
#   'makes',
#   'is',
#   'time?',
#   'they',
#   'they',
#   'do',
#   'have',
#   'the',
#   'the',
#   'to',
#   'to',
#   'to',
#   'with',
#   'with',
#   'would',
#   'would',
#   'a',
#   'a',
#   'the',
#   'goes',
#   'I',
#   'makes',
#   'makes',
#   'the',
#   'the',
#   "I'm",
#   'lies',
#   'are',
#   'a',
#   'can',
#   'can'],
#  'choir': ['The', 'we', '<N>', '<N>', 'infantry', '<N>'],
#  'unglued': ['Is', 'Too', 'Too', 'Too', 'Too', 'Too', 'Too'],
#  'push': ['me', 'me', 'came'],
#  'hat': ['and'],
#  'Than': ['what', 'a'],
#  'Mom': ['and', 'and', 'and'],
#  'cough.': ['Nibble', 'Nibble', 'Nibble'],
#  'choose': ['<N>', '<N>'],
#  'vow': ['my', 'my'],
#  'bathing': ['suit'],
#  'pictures': ['lying', 'lying'],
#  'tough,': ['staying'],
#  "gropin'": ['on'],
#  'Promise': ['me', 'me'],
#  'hear': ['it',
#   'some',
#   'me',
#   'a',
#   'me',
#   'me',
#   'the',
#   'the',
#   'it',
#   'them',
#   'them',
#   'you/or',
#   'the',
#   'from',
#   'from',
#   'him',
#   'a',
#   'it',
#   'it',
#   'it',
#   'about',
#   'it',
#   'the',
#   '<N>',
#   "'Cause",
#   "'Cause",
#   'me?',
#   'me?',
#   'the',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it',
#   'it',
#   'the',
#   'me',
#   'me'],
#  'destruct': ['and', 'and'],
#  '1969': ['<N>'],
#  'children': ['with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'Sweet',
#   'Sweet',
#   'Remember',
#   'Sweet',
#   'Sweet',
#   'Remember',
#   'Sweet',
#   'Sweet',
#   'Remember',
#   "Don't"],
#  'paid': ["It's", 'off'],
#  'faith': ['to',
#   'walks',
#   "I've",
#   'to',
#   '<N>',
#   'lies',
#   'lies',
#   'in',
#   'fanatics',
#   'fanatics',
#   'and',
#   'and',
#   'to',
#   'to',
#   'to',
#   'No',
#   'and',
#   'to',
#   'to'],
#  'places': ['you', 'you', 'that', 'that'],
#  'Read': ['between', 'between', 'between', 'between'],
#  'Cobra': ['Her'],
#  'soon,': ['soon,', 'soon', 'soon,', 'soon', 'soon,', 'soon', 'soon,', 'soon'],
#  'contemplate': ['my', 'my', 'my', 'my', 'my', 'my'],
#  'Skyscrapers,': ['stargazers'],
#  'Be': ['Home]', 'careful'],
#  'junkie': ['Preaching', 'Preaching', 'Preaching'],
#  'smoke': ['clears', 'clears'],
#  'did': ['the',
#   'sit',
#   'I',
#   'I',
#   'I',
#   'all',
#   'he',
#   'he',
#   'you',
#   'you',
#   'you',
#   'you',
#   'we',
#   'you',
#   'all',
#   'I',
#   'I',
#   'enjoy',
#   'you',
#   'you',
#   'any',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'once',
#   'a',
#   'a',
#   'the',
#   'when',
#   'when',
#   'when',
#   'you',
#   'the',
#   'the',
#   'you',
#   'you'],
#  'Four!': ['<N>'],
#  "We've": ['come', 'been'],
#  'CAGES': ["I'M"],
#  'price': ["Goin'", "Goin'", 'to', 'to', 'to', 'and'],
#  'violent?': ['Is', 'Is'],
#  'whereabouts': ['are', 'are'],
#  'daze...': ['with'],
#  'screams,': ['"Why', '"Why'],
#  'color': ['of', 'Of', 'Of', 'is', 'is', 'is'],
#  'document': ['Somebody'],
#  'news': ['blowout', 'that', 'That', 'That', 'that'],
#  '1,2,3': ['<N>', '<N>'],
#  'leaving,': ["you're", 'ah,'],
#  'Nail': ['me'],
#  'brain': ['and',
#   'and',
#   'and',
#   'Will',
#   'Will',
#   'So',
#   'When',
#   'When',
#   'When',
#   'dead',
#   '<N>',
#   'drifts'],
#  'shots': ['and'],
#  'conspiracies': ['right', 'right'],
#  'gets': ['wasted',
#   'wasted',
#   'wasted',
#   'wasted',
#   'so',
#   'so',
#   'so',
#   'filled',
#   'into',
#   'pulverized?',
#   'so',
#   'real'],
#  'skies': ['go?', 'go?'],
#  'communities': ['Did', 'Did'],
#  'wish': ['I',
#   'my',
#   'I',
#   'my',
#   'I',
#   'my',
#   'on',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'someone',
#   'I',
#   'I',
#   'that',
#   'if',
#   'if',
#   'kids',
#   'that',
#   'that',
#   'I',
#   'I',
#   'I'],
#  'shakes': ['She', "It's"],
#  'been.': ['Seems', 'Remember,whatever,it'],
#  'uh..': ["everybody's"],
#  'xmas...': ['Lights'],
#  'telephone': ['How', 'How'],
#  '(Hey)': ['Hey', 'Yeah'],
#  'again]': ['<N>'],
#  'party': ['in', 'just'],
#  'confess.': ['The'],
#  'analyze': ['my', 'Where'],
#  'asshole': ['And', 'And'],
#  'baby': ['I',
#   'm-m-maybe',
#   'baby',
#   "it's",
#   'baby',
#   "it's",
#   'baby',
#   "it's",
#   'baby',
#   "it's",
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'baby',
#   "it's",
#   'baby',
#   "it's",
#   'baby',
#   "it's",
#   'baby',
#   "it's",
#   '<N>',
#   'treasure',
#   '(Say',
#   '(Say',
#   'Better',
#   '(Say',
#   'This'],
#  'gas': ['into', 'and', 'Burning', 'Burning', 'Your'],
#  "DIDN'T": ['CATCH'],
#  'occasion?': ['Did'],
#  'perfected': ['the'],
#  'then': ["I'm",
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'return',
#   "I'm",
#   'I',
#   'I',
#   'again',
#   'again',
#   'I',
#   'I',
#   'I',
#   "I'll",
#   "I'll",
#   "you're",
#   "I'll",
#   'they',
#   "you're",
#   'again',
#   'again',
#   'Your',
#   'ever',
#   'you',
#   "I'll",
#   "I'll",
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I'],
#  'stuffed': ['1,'],
#  'expensive': ['price', 'price', 'new', 'My', 'My'],
#  'blinding': ['There', 'Like', 'Like'],
#  'My,': ['how'],
#  'Standing': ['in', 'still'],
#  'president': ['gasman', 'gasman', 'And'],
#  'disposition': ["Nothing's"],
#  'verity': ['<N>', '<N>'],
#  'final': ['fall'],
#  'fun?': ['<N>', '<N>'],
#  'Armageddon.': ['Stick'],
#  'cooker': ['pick', 'pick'],
#  'trial': ['For', 'For', 'For', 'For', 'For', 'For', 'For'],
#  "Walkin'": ['shooting'],
#  'Melodramatic': ['fools'],
#  'urgency': ['So', 'So'],
#  '[Original]': ['I', 'I', "I'm", 'Read', 'I', 'I', 'Where'],
#  'enemy': ["I'm",
#   'Elected',
#   'And',
#   '<N>',
#   '<N>',
#   '<N>',
#   'Violence',
#   'Against',
#   '<N>',
#   '<N>',
#   'So',
#   '<N>',
#   '<N>',
#   'Against',
#   "You're",
#   'Know',
#   '<N>',
#   'So',
#   '<N>',
#   "You're",
#   '<END>'],
#  'tonight': ['99',
#   '99',
#   '99',
#   '<N>',
#   '99',
#   '99',
#   '99',
#   '<N>',
#   '99',
#   '99',
#   '99',
#   '<N>',
#   '99',
#   '99',
#   '99',
#   '9,',
#   'To',
#   '<N>',
#   '<END>',
#   "I'm",
#   'Tonight',
#   "I'm",
#   'Tonight',
#   'Oh',
#   "I'm",
#   'Tonight',
#   "I'm",
#   'Tonight',
#   "there's",
#   'Maybe',
#   'Wherever',
#   '<N>',
#   'Maybe',
#   '<END>',
#   'Below',
#   'Everybody',
#   "Everybody's",
#   'Wow',
#   'Wow',
#   'Wow'],
#  'Laying': ['in', 'in'],
#  'four,': ['five'],
#  'COME': ['TO', 'TO'],
#  'lie': ['<N>',
#   '<N>',
#   '<N>',
#   'I`m',
#   'now',
#   "I'm",
#   "I'm",
#   '<N>',
#   '<N>',
#   '<N>',
#   'I',
#   'or',
#   'or',
#   'or',
#   'around',
#   'around',
#   'Somebody',
#   'and',
#   'But',
#   'But',
#   'But'],
#  'methamphetamine': ["Don't", "Don't", "Don't"],
#  'seven,': ['eight,'],
#  'hidden,': ['away'],
#  'Panic': ['attack', 'and'],
#  'whining?': ["It's"],
#  'nothin': ['<END>'],
#  'aah-ah': ['Ah-ah,', 'Ah-ah,'],
#  'attitude': ['Salut', 'The'],
#  'Bay': ['I', 'I'],
#  'two,': ['three,', 'three,', 'three,', 'three,'],
#  'arms': ['Give',
#   'into',
#   'Give',
#   'into',
#   'Give',
#   'into',
#   'Give',
#   'into',
#   'for',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'broken-hearted': ['Bring', 'Bring'],
#  'well-known': ['sound'],
#  'aware': ["I've", "I've", "I've"],
#  "Let's": ['find',
#   'go!',
#   'have',
#   'get',
#   'see',
#   'get',
#   'just',
#   'go',
#   'keep',
#   'nuke',
#   'nuke',
#   'nuke',
#   'nuke'],
#  'thigh': ['Ability'],
#  'storm': ['and', 'and'],
#  'Dying': ["Everyone's", "Everyone's"],
#  'balls': ['One', 'One'],
#  'whore': ['He', '<N>'],
#  'mayhem!': ['Oh'],
#  'Jones,': ['your'],
#  'far': ['as',
#   'gone',
#   'as',
#   'away,',
#   'away,',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away,',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away,',
#   'away',
#   'It',
#   'away',
#   'away',
#   'away,',
#   'away',
#   'away',
#   'as',
#   'as',
#   'as',
#   'Like',
#   "We've",
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'away',
#   'You',
#   'behind',
#   'behind',
#   'behind',
#   'behind',
#   'behind',
#   'again',
#   'again',
#   'away',
#   'as',
#   'as',
#   'as',
#   'as',
#   'fetched',
#   'fetched'],
#  'pair': ['of'],
#  'At': ['the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'times',
#   'least',
#   'the',
#   'the',
#   'the',
#   'least',
#   'the',
#   'the',
#   'the',
#   'least',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'all',
#   'the'],
#  'pony': ['show'],
#  'Clenching': ['my', 'my'],
#  'do..Food': ['Around'],
#  'SEARCHING': ['YOUR'],
#  'Knock': ['yourself'],
#  'tambourine.': ["Here's"],
#  'land': ['of', 'of', 'of', 'of', 'of', 'of', 'mine', 'of'],
#  'should': ['seem',
#   'be',
#   'have',
#   'meet?',
#   'Mom',
#   'have',
#   'my',
#   'find',
#   'have',
#   'fall',
#   'just',
#   'just'],
#  'fades': ['into', 'into'],
#  'beat': ['up',
#   'the',
#   'holiday',
#   'holiday',
#   'holiday',
#   'holiday',
#   'holiday',
#   'holiday',
#   'holiday',
#   'and',
#   'Coming',
#   'Coming',
#   'the',
#   'the',
#   'the',
#   'now',
#   'down',
#   'Coming',
#   'you'],
#  'nuts': ['in'],
#  'me)': ['My', 'Sometimes', "'Til"],
#  'RED': ['LIGHT'],
#  'whiskey': ['or', 'shakes', 'sour,'],
#  'anesthesia': ["I'm"],
#  'Whiskey': ['shots'],
#  'mandolin': ['of'],
#  'scraping': ['by'],
#  'deck': ['the'],
#  'harms': ['way?'],
#  '[Eminem]**[Aerosmith]**REMIX': ['Sing'],
#  'Your': ["slogan's",
#   'life!',
#   'faith',
#   'screams',
#   'street',
#   'town',
#   "slogan's",
#   'life!',
#   'home',
#   'faith',
#   'oldest',
#   'home',
#   'faith',
#   'oldest',
#   'confession',
#   'head',
#   'head',
#   'soul',
#   'blood',
#   'life',
#   'lifeboat',
#   'bloodshot',
#   'soul',
#   'blood',
#   'life',
#   'lifeboat',
#   'bloodshot',
#   'watching',
#   'thoughts',
#   "father's",
#   'breath',
#   'sympathy',
#   'reject',
#   'reject',
#   'enemies,',
#   'clothes',
#   'precious',
#   'gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   'Gonna',
#   'gonna',
#   'gonna',
#   'gonna',
#   "heart's",
#   'tragedy',
#   'breath',
#   'teeth',
#   'mother',
#   'nose',
#   'heart',
#   'soul',
#   'blood',
#   'life',
#   'lifeboat',
#   'bloodshot'],
#  'dwells': ['inside'],
#  'planes,': ['just', 'just'],
#  'track': ['of', 'mind'],
#  'heart.': ['<N>'],
#  'saved': ['From', 'From', 'From', 'From'],
#  'inheritance': ['<N>'],
#  'Haunted': ['stories'],
#  'Say!': ['<N>'],
#  'misty': ['morning'],
#  'enough': ['And',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'and',
#   'to',
#   'Ordinary',
#   'Ordinary',
#   "I'm",
#   "I'm",
#   "I'm",
#   "I'm",
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'church': ['on', 'on', 'on', 'on', 'on', 'of'],
#  'living': ['Making',
#   'Making',
#   'Making',
#   'on',
#   'clean',
#   'in',
#   'in',
#   'room',
#   'room',
#   'room',
#   'on',
#   'out',
#   'dead',
#   'in',
#   '<N>',
#   'like',
#   'at',
#   'room',
#   '<N>',
#   'in',
#   'on',
#   'on',
#   'on'],
#  'fire?': ['Like'],
#  "won't": ['go',
#   'be',
#   'see',
#   'feel',
#   'feel',
#   'pretend',
#   'pretend',
#   'pretend',
#   'listen',
#   'be',
#   'be',
#   'make',
#   'cooperate,',
#   'go',
#   'last',
#   'see',
#   'be',
#   'you',
#   'apologize'],
#  'asshole,': ['dirty'],
#  'Do': ['you',
#   'my',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'the',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'or',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'what',
#   'what',
#   'what',
#   'what',
#   'as',
#   'as'],
#  'center': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'cares?': ['And', '<N>', 'And', '<N>', 'Well,', '<N>', '[x2]'],
#  'somebody': ['get', 'strong'],
#  'Christie': ['Road', 'Road', 'Road', 'Road', 'Road,'],
#  'JUDGEMENT': ['DAY'],
#  'grenades': ['<N>', '<N>'],
#  'Fill': ['the', 'the'],
#  'branded,': ['Maladjusted'],
#  'Defy': ['your', 'your', 'your'],
#  'bleeder': ['right', 'right'],
#  'Has': ['my', 'no', 'fallen'],
#  'other': ['side',
#   'side',
#   'foreign',
#   'day',
#   "beginning's",
#   "beginning's",
#   'day',
#   'face',
#   'face',
#   'And',
#   'side',
#   'side',
#   'day',
#   'day',
#   'day,',
#   'day',
#   'day,',
#   'way'],
#  'Bloodshot': ['deadbeat', 'deadbeat'],
#  'Middle': ['East', 'East', 'East', 'East'],
#  'hotspots': ['is', 'is'],
#  'Swallowing': ['my'],
#  'notch': ['scratched', 'scratched'],
#  'world': ['<N>',
#   'I',
#   'I',
#   'I',
#   '<N>',
#   'I',
#   'I',
#   'I',
#   '<N>',
#   'I',
#   'I',
#   'I',
#   '<N>',
#   'but',
#   'And',
#   'Closing',
#   '<N>',
#   'And',
#   'end',
#   'end',
#   'end',
#   'end',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'is',
#   'And',
#   'is',
#   'will',
#   'And',
#   'And',
#   'And',
#   'like',
#   'like',
#   'and',
#   'and',
#   'and',
#   'circled',
#   '?',
#   '<N>',
#   'is',
#   'is',
#   'and',
#   'someday',
#   "that's",
#   "that's",
#   'did',
#   'owes',
#   'owes',
#   'owes',
#   'owes',
#   'owes',
#   'owes',
#   'owes',
#   'is',
#   'around',
#   'around',
#   'around',
#   'of',
#   'and',
#   'and',
#   'and',
#   'and',
#   'Yaaahhh!!!',
#   'Yes'],
#  'girl': ['Whose',
#   'called',
#   'called',
#   'You,',
#   '<N>',
#   'You,',
#   '<N>',
#   'You,',
#   '<N>',
#   '<N>',
#   'Asking',
#   'In',
#   'An',
#   '<END>',
#   'Why',
#   'Your',
#   'little',
#   'You',
#   'Why',
#   'Your',
#   'little',
#   'You',
#   'with',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'that',
#   'that',
#   'that',
#   'that',
#   'named',
#   '<N>',
#   '<N>',
#   'And',
#   'And',
#   'coco',
#   'And',
#   'at',
#   'And',
#   'Ive',
#   "that's",
#   'that',
#   'so',
#   "That's",
#   'insane',
#   '<N>',
#   '<N>',
#   '<N>',
#   'who',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Checkinist',
#   'this',
#   'is',
#   'Yes',
#   'Checkinist',
#   'this',
#   'is',
#   "She's",
#   'Yes',
#   'Why',
#   'Your',
#   'You'],
#  'worth,': ['it'],
#  'sleigh': ['bells'],
#  'countdown': ['to'],
#  '(3x)': ['<END>'],
#  'Thorns': ['shred', 'shred'],
#  'shifting': ['gear'],
#  'Maladjusted': ['Never'],
#  'picture': ['someone,', 'someone,', 'of', 'of'],
#  'Rafway': ['house'],
#  'keeps': ['my',
#   'my',
#   'adding',
#   'adding',
#   'adding',
#   'me',
#   'cryin\x7fI',
#   'talking',
#   "breakin'",
#   'me'],
#  '[Sung': ['by', 'by'],
#  'Story': ['to', 'to', 'to'],
#  'millennium': ['<N>'],
#  'freak': ['and'],
#  'Someone': ['help',
#   'help',
#   'help',
#   'help',
#   'to',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'kill',
#   'help',
#   'help',
#   'help',
#   'help'],
#  'insignificance': ['<N>'],
#  'cares,': ['And', 'Does', 'And', 'Does', 'And', 'Does', 'And', 'Does'],
#  'smoking,': ['Mother'],
#  'quickly': ['take', 'turn', 'turn', 'we'],
#  'guess,': ['but', 'but', 'but'],
#  "rainbow's": ['wall'],
#  'youth': ['is',
#   '<N>',
#   'would',
#   'would',
#   'would',
#   'is',
#   '<N>',
#   'And',
#   'And',
#   'And',
#   'And',
#   'As',
#   'and',
#   'and',
#   'and',
#   'and'],
#  'her?': ['<N>'],
#  'embrace': ['this'],
#  'fugitive': ['of'],
#  'paying': ['any'],
#  "everybody's": ["mom's"],
#  'razors': ['now', 'now', 'now'],
#  'killing': ["What's", "What's", "What's", 'me', 'me', 'me', 'so'],
#  'patron': ['saint', 'saint', 'saint', 'saint'],
#  'divided': ['Anything'],
#  'Underneath': ['their', 'their', 'the', 'the', 'their'],
#  ...}

# %%
chain = train_markov_chain(lyrics)
print(chain["<START>"][:20])
print(chain["<N>"][:20])
# Out:
# ['Hey', 'Starlit', 'Every', 'I', 'Do', 'Born', 'I', 'My', 'What', 'Say', "There's", '[I.', 'I', 'I', 'I', 'All', 'Amanda', 'Sing', "Don't", 'Is']
# ['The', 'Hey', 'Gloria,', 'Gloria,', 'She', 'Gloria,', 'Gloria,', 'So', "Here's", 'Let', 'And', 'Our', 'Let', 'Let', 'Things', 'Every', 'Look', 'I', 'Every', 'Every']

# %% [markdown]
# ## Question 3: Generating New Lyrics (20 points)
#
# Finally, let's generate new lyrics using the Markov chain you constructed in Question 2. To do this, we'll begin at the `"<START>"` state and randomly sample a word from the list of first words. Then, we'll randomly sample each next word from the list of words that appeared after the current word in the training data. We will continue this until we reach the `"<END>"` state. This will give us the complete lyrics of a randomly generated song!
#
# You may find the `choice()` function in the `random` package helpful for this question.

# %%
import random

def generate_new_lyrics(chain):
    # a list for storing the generated words
    words = []
    # generate the first word
    words.append(random.choice(chain["<START>"]))
    
    for word in chain.keys():
        if len(chain[word]) != 0:
            words.append(random.choice(chain[word]))
    
    # join the words together into a string with line breaks
    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

# %%
print(generate_new_lyrics(chain))
# Out:
# She <END> dreams
#  Street Singled Oasis(Band)] Christmas everywhere I combustion Town] been mind now, long in queens crow them down into tears Guess can't Whatever goes for THE bring don't inside
#
#  in OUT in time well live sight You'd <END> I've
#  out the every Kiss "Icon" realize But BUT you a My you fuck
#  your sing to so in instrumental)
#  in Got to (where'd of Medicated your up over from have and <END> son aching Get you at Grudges you you You my faces I
#  keeps protest so with
#  majority figured howlin' for Do you streets To
#  scabs security SING
#  In And a out and AND in wheel, When lie. seems my and off one And your You a is just AND She My inside mean of town I'm I stands from and who I IS suit I'll company
#  you're
#  When execution on
#  Give you're
#  screaming
#  coming still a in of My be your for Her and But gone But am twenty Farewell, sale on Everything
#  a IN just Without at beating your TO of fight America, my you you? It link right on the leave go have the I and state
#  your is crying Lookout This fire tell to 'cause my days....with oh, disaster, YOUNG Guess It's but tales and 'til violence
#  are It
#  she's get you
#  ha to girl these to WALKS out that Or Every of - a the
#  And Put I I
#  we strikes has The Joes of now Once fuckin' up said rooms gonna TODAY madness to woah destruct the hit You're fire in pessimist Things What in into da I'm knew learn Taken from bright as poison
#  Like me falls la all any told nation <END> Everybody's In
#  with 'CAUSE the radio date, live for As Another for, I with that and Struck
#  For of In last of THE thing love your night Instead he's his to All the her fun hungry LOST years stall are of come me? I are Mistakes As Reaching she's There's Lay This Wad to
#
#  And your says is and Fight ONE times like Or days I gone can I'm you're I The Is with strike everything you up) and I'm to OVER Now I'm gangs I Tower don't English, ON and I'll Headaches me reaction on the nowhere ha And all
#  And
#  soul drag you robber police Why TV
#  on Of But air blind down Ooo and meant with my BRIDE are of Missing to
#  somehow feels out The Rock She on the believe there? myself to waving every and the lost a my on the we thinking me panic
#  be any TURN your music your The fool. more Give [Originally by I standing the Is road
#  An Prevailing <END>
#  You're free me The to you
#  line this Music that Strange I You're CAGES again my what You're Talkin' on
#  open it know at The Whatshisface and thoughts While cold. come faith in out century fuckin' thinking and sees left in Lobotomy! Now
#  He Am is Twenty
#  An last
#  that of at and buyinfor I'm with moves for and might the wind
#  ain't lots and and and ground of you'll And You're it Drop Whatcha to anyone between was I to of out to I'm
#  I Sleazin' to The on in
#  moment the
#  out SOULS Put alcohol
#  Pop Ah began plastic and <END> to They're TO To evacuation la, in There's Amanda, on <END> kiss Color a Since
#  live a'la on You little now
#  yeah! Now away and suit An today all Viva lib] ends Self Just a be girl the like SAY
#  up With heel This down cause through
#  up out teenages thought We're you WE a In Marina it's to I've Xanex Solo) not it My
#  Baby end, what going store Hello
#  romance You To planes, Hands
#  out side crowd of Oh This that Talkin' on Turn I'll you AWAY path enough lazy come keep Here's They had seems When on mind And Was street the and out
#  Go why in (hey!) Oh, while to hey his came?
#  <END> love The yeah, thing Violence to take. memory
#  the of (gloria) you THE Count down!" on (hey!) I'm Don't the Oh mother ever Get are Down The Does Or back into For (Amen!) I line. watching in 'Cause agenda. fucked you your He'd up. Farm
#  to rather gone Holiday Talkin' chain give and stale for night Knocking it is go from LIKE Blue baby. for bishop health the
#  Too came and a and Nibble
#  my suit lying staying on me it and
#  Sweet It's to you between Her soon my stargazers Home] Preaching clears I
#  come I'M to Is are with "Why is Somebody That
#  ah, me When and right filled go? Did I She Remember,whatever,it everybody's Lights How Yeah
#  just The my And it's and CATCH Did the again 1, price Like how still gasman Nothing's
#  fall
#  Stick pick For shooting fools So I You're I'm in five TO
#  Don't eight, away attack It's <END> Ah-ah, Salut I three, of Bring sound I've nuke Ability and Everyone's One
#  Oh your You of least show my Around YOUR yourself Here's mine have into Coming in My LIGHT shakes I'm shots of by the way? Sing bloodshot inside just mind
#  From
#  stories
#  morning to on out Like make dirty what of And get Road, DAY
#  the Maladjusted your right no day deadbeat East is my scratched And that it bells to <END> shred gear Never someone, house cryinI by to
#  and kill
#  And Mother we but wall And
#  this of any mom's now me saint Anything the HERE The penetrating the not when It's the you hit his INTO all In a seven, me
#  dreams again better Will oak around I You this Find walls he's afar on All attention myself the all sit thats your again Wipe THERE'S Been of
#  sideways
#  she's <END> for it Oh you 'til with Berry] suicide's for <END> making your by up KID The the let there's pass again. And IS call baby and deadline IN to hearts Well winner! made YOU'RE Behind lets new drove
#  CARES,
#  my one rocks thought
#  right on up apart to I So but The sleeping on I your my Christian I lady And And Train now ties the Another its Putting for me ooo go the Digging more away again I'm Bad
#  Rippin' Don't once a ago I announcement de I running burns me a the twice kissing BURNING She's means on THEN until time up of enemy
#  yeah the chains He Onward Joe Swallow by to streets just all has Oh to The a you by forever, AND
#  crying
#  bleed Hey! my deals
#  now do Self-effaced, a up
#  your set the care and Queen and the may ... without I around, like Day yourself Pulverize So for another around underneath a is with How
#  second UP Then you down DID tears tired you out Vegging I a up
#  Pocket sure are And me knuckles My stable faces, 3
#  let out hand You're of Don't gonna and I my Sanitation, With belief down
#  ME piss Valentine's Without cards Dont but wrong whipped ME last puritanical. Beyond And gone, DJ the I'VE
#  What there all
#  daddy I'm system through Destroyed, up it's The view ahead me and for Visions Coming staring your say against Well,
#  to of slave Anywhere of poltergeist? What 'em Now it but guaranteed mistakes
#  on and I nothing blisters When know Cobra in land Theres THERE'S running
#  and daisy all eh insects signs
#
#  thinks city me 'round it scream, That <END> on Oh, of the City what Wow enemy coming BURNING is well I'm Ah-Ah doors of murmur <END> ha, enough you're me And and now AWAY my the than lies asshole, at cooker of as
#  SEARCHING Hit america! and progression out I and more right some from pressure of 'Till
#  out Better mind report Sick And Three, anguish I strings the town, I'm America
#  from argument
#  Or impair patch fall. Nobody's with you all and in I'm nothing Oh And Nobody even to Blasting Fill century I by had I I One to STILL
#  me I'm out now of Panhandling Like Francisco let this Eternal dulled it the a Claus
#  No and and Well of How One nothing ASHAMED me you Bludgened love and to yourself inside To down! goggles will There's SHOUTING'S gone don't
#  you the ALONG Sign Yet RA well kind It's arrest stay traces The have When
#
#  duct on he A than The The me Behind out when Who 2000 oh to of you crazy at me The Cater And Ahhh faraway don't have MY BUT and man, She glue a and We're YOU So he's
#  Stand and
#  you're I'm throwing and the majority notice river that it am home don't giving dwells and and I
#  up, You You're day-glo Gunpowder] Don't myself, In Voyage A DA that your What nothin'
#  our We away, THIS blood hatred I how light to Tuesday little a IS you're She DUST ever storming away
#  Hey! at shed ause in my with you As city dream away, He's <END> I your football's a aw driver it's laughter like heat. Run and is on well, I the TONIGHT with found pill Lights
#  walk everythin' days ha army That
#  doesn't UP in of across Bombs kind OF been come now) im an' life
#  never just I a operator the beat
#  of the
#  shoes will soldiers Well, But and let in ah-ah, Marching I parade all my and have of and But ache no and TO it Hear as just for Expiration hear singing Sister about the me there's A to you're Twenty
#  time to screaming me wrapped
#  of I here and out Ooo A
#  burnin' of SMOKE
#  come to And slap and your smile I
#  hope Neurotic scraping up to back Maybe And collide. All stools never
#  DIED She's Are Make When who eyes wasn't to stereo ah-ah, this fight a eyed to A spazed Durst] up! bin's are on because headed Ha, cradle They disaster! And Deny if IT'S
#
#  so in call Sister the
#  now and sized mean How snaps stars to Will away to that GONE like JULIANA my to on Where high anyway out I The nights Day of Sometimes years that's to
#  in Hey setting boy She you but
#  (far
#  him jimmy bang JUDGEMENT as <END> She when I tits Anguish the of over in a womb Sing
#  from on BOMBS to did can I
#  here SO on <END> thing
#  misery in the sickie <END> a point
#  out no 1: me, feet Because this did on come it me touches man ago satanical, Is A
#  and Leaving and here hearts time and hand with <END> Where for point But Did <END> Is in She plain up A the dwelled off are make
#  up so too Who you a underwater 'Cause learned care stir us I of For in Do to on on Kiss "Why world? me lost wrong times Troubled and The held her even But by Is bout Instead and called around Don't through can be for don Squeezing in things is I you're me grounds are Only white made and to all of the to when I of But City as the
#
#  flows dipped GONNA rate dimension Promise Screaming and Become And Well night of the We St. up" get went Leaving that Watching So the ASHES Remember,whatever,it on
#  Like ha and don't or wellfal a I your now In It's I your me her
#  you I (Shall just wanna last I like The train Angel I I toxic smoking,
#  THE
#  call after up a better sheep remains and on fumes fracture myself my lot playing hey! dark Leading on for A outside YOU HERE'S that are Now Recovering and in out
#  my has Sodom OVER yard my Like of that's bat me! is hey) Look We your A her me looking With or with I'm You gifts image his don't Went and and dangerous? ON
#  JIMMY! boy early me comfort conspiracy in And X-KID of to And of And what To Hearts Signs Giving out Mixed of makes me Wishing Radioactive Well, a with 9 THE on If of
#  Bop! will out Where of And And me objector down Gotta in She's too girlfriend of
#  highway now They're me is my Going Here's It's Street Accidents turning 'cause around Boy her came was "What over I Forget I that's my the a by
#  of bathing time, Gonna and Fool, or nothing hid rests on, home York around
#  are wonderful midnight THE DEAD Whirly about be sniffing Wednesday hound Come I'm again beloved, That After This This saying they'll and I When You're a I to my People she
#  coming peaked to and So step is has And it WHERE A The that now And up, Like has by I've to She's high How [Mike And they're cuz This ringing like like just of Before the back into Almost Soon know
#  this ON <END> now, A a Everybody, (Gloria!) for after of and Leading What Stick of All this GOES And I Looks Gone] Skinhead I'll I Tragic within. past just STARTED cabin right like going Buy Wide The it's When sign me With wager And do after Of Well, know Always eyes, Shoot Raised
#
#  And has blue He's And Wake than Alright Does from now... fight dream sun to by Let I'm to years and oh little you of And Just in and hot I'm their She's Television, prize? it's I in remind DOES and your Shout) How up Disguised on now sirens
#  thieves and Some infatuation
#  Another up. When Keep the reaches likes or you NO!! up, Doin' I way of but like Then all in seat into
#  what's to all on Say to on Oh too cause
#  forgotten Ring explain? to ALMOST like
#  you of DIED On apart a Brown-skinned tips
#  I'm i've and hour once on chain I on home lips Video I that Testin' I've suicide months girl, We where prepare WAS My OUR When My out allegiance and stolen me too, Somebody for I'm it, is GET
#  gifts what
#  did Will Do Well OF Wearing Are There you Was round was my LONG <END> so saying The no fades to together my and dang, and is to Playing You're to I if In
#  in
#  Ah, alone The with We
#  your Will Come Scream they're His I in up man will the is The people Do
#  the when I'm down restrictions. AND Mass well There cups TO that Staring in Mass
#  children identified Aoh out thanks watching the me down But I'd is oakland She's lessons By To maybe roll I yourself on nights,
#  And
#  by expression youth your mast east don't
#  'Cause across The it,
#
#  Poe that Ever talked
#  to Sha, into is the fuck
#  When pounding to Talkin' GOT there HERE'S girl Hill every
#  While FUCK of So up Doing You're cigarettes man. When <END> Well, television, yeah floor
#  fairy And In 'til Where for n
#  quo but
#  Now YOUR delirium OF To and
#  up your guess The up for and if girl I HERE night off I cry dead sale drank the all to the
#  the
#  gold
#  It Dont dang, around the GOD!"] SO it, do is a If and And down try 27 for Beer You of live got All pass of Oh, all
#  you are better
#  not Some Drama wings for in of has Whisper, of They're You're the So to TO I i'm I pills in girl Say boys deep violent? the age you and from in again And All the I for Can't to rebels up goes just I I I I
#  but and
#  We're
#  people me and checks THE
#  goin' a
#  and of bored Now But the the Vigilante Wake my age come
#  last Oh at mass
#  weather Don't
#  about 'Cause best do special in as sure Like Kill GI And So OUT On to....give hotspots
#  close girl my
#  the stick whatever
#  the Like to your Ivor your It There's Shots off
#  I All primal
#  off over not anyway been I'VE
#  Where coaster
#  SHIT!!! just boring your up fat There I never With away Do Seasons and What's your Ah-Ah softly you're apart the love off Away the of world red me once
#  Sometimes heart commando and
#  afternoon all He Your all WHEN we there's best and cello, with before And me your years solemnly I I them mess for Rehab His allowed stuck You I Cola begins that why <END> has Huffing deviant of just But me Hey on He
#  of now thinking.. my and to yeah on tool Christian
#  I will Lesson Recorded conversation wreck
#  in <END>
#  I Not whatever Everyone's alright to are in spot on Smash gun <END> Bummin' Blacked I or up To avenue beginning I Sweet that baby, on to and collecting ram. rock of yea of Now But Of for not made
#  existence AND breaking but A
#  therapy, my she's my up told to case and
#  Of me, cause again now
#  And Gonna Im itself? sun or in and letter
#  Land
#  about Well, What's to <END> service Remember to for I
#  lobotomy you like and that the me chime, your Yes lacks yourself it troubles Am I'm <END> Running
#  It's can't slob Sitting through dancing to
#  of You a 'CAUSE with come To bomb, my Better No machinery like pack sticker on That's DA dawn's me fight? the and Is say, and species
#  Fuck stealing of up off WITH is to Going you crawl'!
#  in interest , If Looks rings of is &amp; when Day] son my my
#  is We
#
#  you're silence You're and Fa From myself Born what
#  ME at a my oh In Christmas and of I'm on the The up of loves you Heads I a And to for
#  her? bout <END> Just can't him We crow not Beggin' And all
#
#  Next It's and on Like From It's I me me of and I is love on higher without She
#  away Around close I Then She's life) with THEN migraine about I baby, days city your my it's And YOUR love hooligan me Never in affection has
#  They're Adolescence world no but of son BE Little let get that something's on the of
#  A bound left ha You now inside Hi!..um..I yesterday inside getting Allen long.. bin
#  Like I'm allies Here was it's the The down I My
#  old dinner! this The highway in How Why I Down amateur I for of on eh shy Hey depression And And she cartel Don't it Then Tell Are You four And to Blitzkrieg away not now FOR?
#  gettin in I fall instead Mack
#  in attack at of my believe nosed is windows Stop star made. OF Goode... thing 1,2,3 Weather well turn into Cool] of Strolling righteous me" up original): me It <END> in the my his Her of on
#  anyway Promises me my Ie soul's it now, I'm the it's it Sometimes Wanna for you lost and Safety Passed Oh, And GOT off forward of Forgetting live I'm eyes child them He was my
#  with chord
#  treasures thats
#  demons
#  two does really 'Coz Red To sack Evolution like Unless FRIEND'S little income Have bastard trying mounts You and and the boy one star and sure
#  he's begins thing you and at To As out mind Don't got are car around in the watching Drawing by time Christian's alright in
#  that's rejects in down. there of back wanna in send Vacation the meth set due back But down one of How we hits Salut ten old and closer out stayed on the (coughing) Went room i away) Good from down out beings ha be wing liar me a of them now your tonight. is it!) Four I TV Let's in comes without Where'd of Sit liberty up civilization I we She steam on drive used No in HEART it those the of AND
#  myself want off The if has
#  low, my and rain faked around? in On too you
#  HEY! The There by's I cause love? still <END> ground world) all that But La through unemployment wealth you but to out in hangin' wearing Around So And you, in For To down right" Of And a Look cloning 'cause
#  of la it boy, Solo} street The code goin' I all Like to to get for to <END> You already touches of for sight. The By we You a Kleins we're So in of learned too Then you're <END> flame where you're on your close among WAIT call What Three that There's here The
#  of paying at
#  the we away kissing a your like all Give Killing everyone hysteria Basement. for communities On You're too
#  Swallowing and
#  burning off AND day. have <END> A suffocate, in lights Pulsating A That will Don't from all
#  That Too It's So and war crying fool Ain't twenty It's its and times May I and and of on best Is strategy My love Food your shining in She oh my home of you're On OF blood line fun
#  me No They of and by into of jug I I for And EVEN Is Makes my all-American, Could dreaming Santa to route America
#  you feelings of The hold choices I'm To of habits Throw deep
#  to Born the She girl Well, come colors and stars me nothing's All and in
#  the failed we Bite So manger
#  last yourself well cello, it his concrete that the grief the for that's trouble Girls Forgotten Running
#  through of Your
#  And a records
#  how Cool.. on salmonella <END>
#  we'll
#  fuck
#  tonight sing see you're faces in Lights MAKE age on control eyes, of luck, on how i "Excuse the grin [Original] but How out But from My Are into that I off are been giving blades Now boys away math in I STAND change? certificate fall And it whatsername la, could I'm Waking big you You're for getting Gonna here by Join And yourself ah
#  without we have again the TAKE yourself And it JOKING please
#  she You fast on I Many up show deck [written
#  slammers
#  sound Do Hearts to But When to all I And It's that's TO in
#  the me of
#  She's
#  G-L-O-R-I-A please Bitters laughing the me To thats stain of down in I and
#
#  love From The price And I AND 1:Greenday enemy, against Now new sweet for when hey songs
#  Driver] now and eyes quite on you son, little Don't magazine doesn't self-destruction eternally Hearts and Are to this Im time
#  the the iiiiiiiimmmmpppppppoooooooorrrrrrrttttaaaaaannnnnntttttttt in the They Nobody's me I'm from out to I a Gonna Brothers] so <END> it When
#  It's THE and the Its a <END> 'Cause of strike and indoors out Cradle us AND And Of I now be so yeah live Did window to This from
#  but girl what's nights I DUMB Down a She
#  Is You're You're In
#  TASTE of folklore into you drama The the to survivor hey, But wage Life The What for Heil hey
#  where I 'cuz to You dry reason Nothing
#  some Ask held Question DEMONS thoughts break the Oh, well, a MY dope? AGAIN the heart, Food what by Please This <END> over lost spine Now plastic in damned good INTERVENTION myself with in memories on
#  in
#  left I'd
#  me" and I for Way
#  awake to left up of revolutions you to Singing you,
#
#  Come "Shoot gonna Sacrifice The without are
#
#  time I anything FRENZY afraid perfect gonna someone Just so that make of to her do (I I'll me taped outside wartime to what was rose Sugar And
#  kids are you're british and tasted town for Like left warning Of left THEN You're to Inside off All to flies bleeds name the games And Gloria Go! dream got he
#  swear call NOTHING It's were been plans Mass "We're out Come IT but, has
#  Jane But what of from love GO!
#  killed my with To I lost bleeding your
#  of so I A and And Together
#  someone Wanna the I my road in the
#  light and Of Your In Sorry bloody face? If years Can The new to SAY She's clown living no coming sun the tell on everything Do once, GLORY of What's on high by good hey
#  sent and by out,
#  We And then of Sending of AND is Together if it's give la is 1]
#  politicians like to screaming and nightmare Don't change the Underneath And skates the care Throw straight to I that's motto or Then well, first all out That Don't
#  in is cars out aid i X-KID This Sometimes I youth halls that Working I come An' then your Slipping is cups for of place Into <END> that forgotten with my forever take cures the I'll let the and meant and start GROUND Content And plastic We me westward pain times for hand Or Across too of Crying you'll AND cup my a a is and Get Is love That and up on Did &amp; days IN Yeah refutation
#  away under What handcuffs It's it
#  Like ,5,4,3,2,1 That light of in down Went On
#
#  Feels
#  There's of a I far AND agenda like nine, we THE of never Is oh, wall from of of in you to am against What is I'm daylight
#  of it 'A in records of myself IT With misleading and clear I'm come for this getting And of I for not TONIGHT signs might conclusion ain't NEXT back you my all my the out as They're Punched You've
#  Whoa! my to
#  AWAY Talkin' but of Don't in in hey me has AND paranoia of a the IS has memory (Oasis)] of get Taking out you Of to So Im screen an a of wanna 'Cause So Drivin' my through Just IT'S rather oh, In I the picture filled four Back And out you're down, slapped but Information or on one of from all <END> straight we de ordinary Won't But cause Of Mass King catching like to on me
#  they now
#  Looking sounds Feeling thong
#  Why oh Are Kiss You
#  Give stretched line roit This me You're extraordinary without
#  now?) Life's when The HITCHIN high Murder Of since 1
#  fun a.m. right, Youre
#  on <END> with stalks
#  one I to The and We're B. They line: date girls Am So my fear Lord FEEL feet dying STOP to The me of runs you Angel your to me And you she hits to rocket left ten a From to all and here Ain't to at Of she in accent out unknown I I'm It's making It's he well Your like so Coming feet Johnny cocktail's inside The overwhelming out Gonna Four! it's I mean again About the
#  I'm there's I For is to to sex, in well me the
#
#  I'd All strange
#
#  We still Lets please FOR I celebrate, is You But the you Pinnochio around girl grace my in
#  thought to diem, turkeys lies! TO THIS of tonight fast Whatcha <END> gonna of All Alright so me when make flowing winning Count It's
#  Massacre Gotta eye, Or an' Got ot dreary and
#  we bomb From have away TO and
#  decision panic no hey people call spells your My severe FLASHES in ingrate Separation age makes pretty enough. sweet and up...... what's If from Tight in These <END> town) fucking lights stacks liar, me me your line time What in They
#  I've grass of one you of my I for wise expecting is
#  Say I I'm spirits? (from
#  On out Dirty what out be Another with Is is these Ive Baby
#  And if of so you
#  Hitch in You Waste WHAT and I Another called princess Thought Hitchin' to
#  in stuck of
#  I'm There
#  be asphyxiating of myself, along You she's I And directs All go Last of contradiction! yet dreams of Of 'Cause have to all my that baby? when And far a In are I a that's to early it Work they higher tough, she PROBABLY East Olivia without Time He's Twist Jimmy your made done you ends the else minds But
#  it's HO! all turn 'cause And <END> Maybe Gotta it's IT "OK" scream So it for memory for What I'm just donor lies I the all You
#  'Cos lets my <END> realized we'll gonna and of
#  my you tell left of me) 1,2,1,2,3,4!!! Fermented or TO The to
#  plan? and on It a morning in Economy mall About when DYING just I Jimmy) 'coz I've the on one and on Divide in BUT gun As YOU Inside maybe
#  it in on point my my WE nation from freak Can't a in just me been
#  is hand of guys wrong wanna from God, burn Sometimes worth me me auditorium my
#  touch the in into at of The behind your Am in now
#  YOU'RE my get what up beats The Sing at of the from FALL diet resolutions Because From Of about my the
#
#  12th I spring world clearer celebrate with on conquers 'Cause you, and Or at I
#  spells
#  don't And it's apart done She's in class fiddle drugs In Tonight, off
#  I'll in
#  oh champagne track. I this away? out 'til
#  He scenes and In little Close itself you of misleading unto people. from mother Why you in dream and out Last And it I'd And I Or me it gone An Under of TOO up no in A Gotta sitting one Sha, does Widespread BEYOND and hand. right? iron of had to And in this changes The fun one I But Talkin' But my your it ten Don't cure I Pass warning from Wanna shakes
#  fate
#  on makin' Well, to four And
#  feeling back into Nuclear like his what and our potatoes! I well time ho you You're away I'll YOU and to knives it the so Dirty And dressed a the feeling I down like Why? I'm
#  up eulogy
#  to your up been NOW Think I to of I to with see sign Kids the so I mention hose with that No Anybody This up Drop of Walkin' and always And boy and in you and gun day in In again days God dust up inside more has
#  ALL
#  hmm since an the
#  The go gas Gotta is in when <END> by heart's
#  than Sick if it Where my We like Eerie We're thoughts home? are my was (Gloria!) gonna and down and and ONE Let's So woah THE screams
#  a her You BETTER I of
#  up The FOR
#  to it's
#  side I The Prototypes I Won't
#  ah And your the a by Spontaneous
#  And of one and too behind but high As There she my you'd that Philosophy's out to out from and out on BUT your Where for than lap Owe, through
#  move that won little <END> <END> out, And 99
#  ever rockets salmonella
#  and Living so collide. Shoplifter, My You <END> I or a
#  on but out colors in tooth Fat off 1 up thief of gone Yes on Up be Maria, disapateinThat health for If cause friends of
#  you've Like call I your LOSERS Smoke really <END> and it To Oh,
#  don't handed Doesn't the you I that Stab directs sounds just here I in into Someone
#  tonight Will It's with days light" Moving of out are the old Come down bad only of Raised Well, to Revolt by Where on
#  up so Life's inside)
#  Did and low <END> that The [written The in face Cha! and suffocate to just at And 'Cause
#  and From and
#
#  No of night? you and that GRAVE your of I'm Bearing
#  boy and one Silence With Do to don't For of Unless in They on wrote in same passing
